# %%
from defectlib import extract_features_from_defect, train_svm_classifier, plot_tsne
import numpy as np
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
features, labels, sns, images = extract_features_from_defect('./reverse/MCEW-RF/', comb=True)
features_test, labels_test, sns_test, images_test = extract_features_from_defect('./defect_tensors_D10/MCEW-RF/', comb=True)

features_all = np.concatenate((features, features_test))
labels_all = np.concatenate((labels, labels_test))
sns_all = np.concatenate((sns, sns_test))
images_all = np.concatenate((images, images_test))
# Out:
# there are 321 images inside MCEW-RF_2A_c10
# Processing ./reverse/MCEW-RF/2A/MCEW-RF_2A_c10/MCEW-RFRecombination_F3Y648702U7H3RPA_2A_0.jpg...
# Processing ./reverse/MCEW-RF/2A/MCEW-RF_2A_c10/MCEW-RFRecombination_F3Y6497004ZGY4RA_2A_6.jpg...
# Processing ./reverse/MCEW-RF/2A/MCEW-RF_2A_c10/MCEW-RFRecombination_F3Y65050NCVGY4TB_2A_7.jpg...
# Processing ./reverse/MCEW-RF/2A/MCEW-RF_2A_c10/MCEW-RFRecombination_F3Y650513BDGY4TB_2A_8.jpg...
# there are 243 images inside MCEW-RF_2A_c7
# Processing ./reverse/MCEW-RF/2A/MCEW-RF_2A_c7/MCEW-RFRecombination_F3Y64760BGAH3RPA_2A_0.jpg...
# Processing ./reverse/MCEW-RF/2A/MCEW-RF_2A_c7/MCEW-RFRecombination_F3Y650206EYGY2VA_2A_7.jpg...
# Processing ./reverse/MCEW-RF/2A/MCEW-RF_2A_c7/MCEW-RFRecombination_F3Y65050E0HGY4VC_2A_0.jpg...
# there are 50 images inside MCEW-RF_6A_c10
# Processing ./reverse/MCEW-RF/6A/MCEW-RF_6A_c10/MCEW-RFRecombination_F3Y648702U7H3RPA_6A_0.jpg...
# there are 158 images inside MCEW-RF_2A_c0
# Processing ./defect_tensors_D10/MCEW-RF/2A/MCEW-RF_2A_c0/MECW-RFRecombination_0_2A_0.jpg...
# Processing ./defect_tensors_D10/MCEW-RF/2A/MCEW-RF_2A_c0/MECW-RFRecombination_5_2A_4.jpg...
# there are 130 images inside MCEW-RF_2A_c10
# Processing ./defect_tensors_D10/MCEW-RF/2A/MCEW-RF_2A_c10/MCEW-RFRecombination_F3Y64910QY3GY4RA_2A_0.jpg...
# Processing ./defect_tensors_D10/MCEW-RF/2A/MCEW-RF_2A_c10/MCEW-RFRecombination_F3Y64960AEKGY4TA_2A_4.jpg...
# there are 152 images inside MCEW-RF_2A_c7
# Processing ./defect_tensors_D10/MCEW-RF/2A/MCEW-RF_2A_c7/MCEW-RFRecombination_F3Y649112PTGY4TA_2A_0.jpg...
# Processing ./defect_tensors_D10/MCEW-RF/2A/MCEW-RF_2A_c7/MCEW-RFRecombination_F3Y64940ENNGY4TA_2A_1.jpg...
# there are 103 images inside MCEW-RF_6A_c10
# Processing ./defect_tensors_D10/MCEW-RF/6A/MCEW-RF_6A_c10/MCEW-RFRecombination_F3Y64910QY3GY4RA_6A_0.jpg...
# Processing ./defect_tensors_D10/MCEW-RF/6A/MCEW-RF_6A_c10/MCEW-RFRecombination_F3Y64960AENGY4TA_6A_7.jpg...
# there are 95 images inside MCEW-RF_6A_c7
# Processing ./defect_tensors_D10/MCEW-RF/6A/MCEW-RF_6A_c7/MCEW-RFRecombination_F3Y649112PTGY4TA_6A_0.jpg...
# there are 101 images inside MECW-RF_6A_c0
# Processing ./defect_tensors_D10/MCEW-RF/6A/MECW-RF_6A_c0/MECW-RFRecombination_0_6A_0.jpg...
# Processing ./defect_tensors_D10/MCEW-RF/6A/MECW-RF_6A_c0/MECW-RFRecombination_9_6A_9.jpg...

# %%
plot_tsne(features_all, labels_all, images_all, perplexity=30, interactive=False)

# %%
train_svm_classifier(features_all, labels_all, sns_all, 'model.model', split=True)
# Out:
# train test split == True
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [CV] kernel=linear, C=1 ..............................................
# [CV] ............... kernel=linear, C=1, score=0.967647, total=   3.0s
# [CV] kernel=linear, C=1 ..............................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.5s remaining:    0.0s
# [CV] ............... kernel=linear, C=1, score=0.952522, total=   3.0s
# [CV] kernel=linear, C=1 ..............................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    7.0s remaining:    0.0s
# [CV] ............... kernel=linear, C=1, score=0.970326, total=   3.0s
# [CV] kernel=linear, C=10 .............................................
# [CV] .............. kernel=linear, C=10, score=0.979412, total=   2.3s
# [CV] kernel=linear, C=10 .............................................
# [CV] .............. kernel=linear, C=10, score=0.976261, total=   2.3s
# [CV] kernel=linear, C=10 .............................................
# [CV] .............. kernel=linear, C=10, score=0.976261, total=   2.3s
# [CV] kernel=linear, C=100 ............................................
# [CV] ............. kernel=linear, C=100, score=0.979412, total=   2.3s
# [CV] kernel=linear, C=100 ............................................
# [CV] ............. kernel=linear, C=100, score=0.976261, total=   2.3s
# [CV] kernel=linear, C=100 ............................................
# [CV] ............. kernel=linear, C=100, score=0.976261, total=   2.3s
# [CV] kernel=linear, C=1000 ...........................................
# [CV] ............ kernel=linear, C=1000, score=0.979412, total=   2.3s
# [CV] kernel=linear, C=1000 ...........................................
# [CV] ............ kernel=linear, C=1000, score=0.976261, total=   2.3s
# [CV] kernel=linear, C=1000 ...........................................
# [CV] ............ kernel=linear, C=1000, score=0.976261, total=   2.3s
# [CV] kernel=rbf, C=1, gamma=0.01 .....................................
# [CV] ...... kernel=rbf, C=1, gamma=0.01, score=0.435294, total=   4.7s
# [CV] kernel=rbf, C=1, gamma=0.01 .....................................
# [CV] ...... kernel=rbf, C=1, gamma=0.01, score=0.436202, total=   4.8s
# [CV] kernel=rbf, C=1, gamma=0.01 .....................................
# [CV] ...... kernel=rbf, C=1, gamma=0.01, score=0.436202, total=   4.8s
# [CV] kernel=rbf, C=1, gamma=0.001 ....................................
# [CV] ..... kernel=rbf, C=1, gamma=0.001, score=0.435294, total=   4.8s
# [CV] kernel=rbf, C=1, gamma=0.001 ....................................
# [CV] ..... kernel=rbf, C=1, gamma=0.001, score=0.436202, total=   4.9s
# [CV] kernel=rbf, C=1, gamma=0.001 ....................................
# [CV] ..... kernel=rbf, C=1, gamma=0.001, score=0.436202, total=   4.8s
# [CV] kernel=rbf, C=1, gamma=0.0001 ...................................
# [CV] .... kernel=rbf, C=1, gamma=0.0001, score=0.435294, total=   4.6s
# [CV] kernel=rbf, C=1, gamma=0.0001 ...................................
# [CV] .... kernel=rbf, C=1, gamma=0.0001, score=0.436202, total=   4.6s
# [CV] kernel=rbf, C=1, gamma=0.0001 ...................................
# [CV] .... kernel=rbf, C=1, gamma=0.0001, score=0.436202, total=   4.7s
# [CV] kernel=rbf, C=1, gamma=1e-05 ....................................
# [CV] ..... kernel=rbf, C=1, gamma=1e-05, score=0.435294, total=   4.5s
# [CV] kernel=rbf, C=1, gamma=1e-05 ....................................
# [CV] ..... kernel=rbf, C=1, gamma=1e-05, score=0.436202, total=   4.6s
# [CV] kernel=rbf, C=1, gamma=1e-05 ....................................
# [CV] ..... kernel=rbf, C=1, gamma=1e-05, score=0.436202, total=   4.6s
# [CV] kernel=rbf, C=10, gamma=0.01 ....................................
# [CV] ..... kernel=rbf, C=10, gamma=0.01, score=0.844118, total=   4.3s
# [CV] kernel=rbf, C=10, gamma=0.01 ....................................
# [CV] ..... kernel=rbf, C=10, gamma=0.01, score=0.863501, total=   4.4s
# [CV] kernel=rbf, C=10, gamma=0.01 ....................................
# [CV] ..... kernel=rbf, C=10, gamma=0.01, score=0.839763, total=   4.4s
# [CV] kernel=rbf, C=10, gamma=0.001 ...................................
# [CV] .... kernel=rbf, C=10, gamma=0.001, score=0.435294, total=   4.7s
# [CV] kernel=rbf, C=10, gamma=0.001 ...................................
# [CV] .... kernel=rbf, C=10, gamma=0.001, score=0.436202, total=   4.9s
# [CV] kernel=rbf, C=10, gamma=0.001 ...................................
# [CV] .... kernel=rbf, C=10, gamma=0.001, score=0.436202, total=   4.8s
# [CV] kernel=rbf, C=10, gamma=0.0001 ..................................
# [CV] ... kernel=rbf, C=10, gamma=0.0001, score=0.435294, total=   4.8s
# [CV] kernel=rbf, C=10, gamma=0.0001 ..................................
# [CV] ... kernel=rbf, C=10, gamma=0.0001, score=0.436202, total=   4.8s
# [CV] kernel=rbf, C=10, gamma=0.0001 ..................................
# [CV] ... kernel=rbf, C=10, gamma=0.0001, score=0.436202, total=   4.7s
# [CV] kernel=rbf, C=10, gamma=1e-05 ...................................
# [CV] .... kernel=rbf, C=10, gamma=1e-05, score=0.435294, total=   4.6s
# [CV] kernel=rbf, C=10, gamma=1e-05 ...................................
# [CV] .... kernel=rbf, C=10, gamma=1e-05, score=0.436202, total=   4.7s
# [CV] kernel=rbf, C=10, gamma=1e-05 ...................................
# [CV] .... kernel=rbf, C=10, gamma=1e-05, score=0.436202, total=   4.6s
# [CV] kernel=rbf, C=100, gamma=0.01 ...................................
# [CV] .... kernel=rbf, C=100, gamma=0.01, score=0.976471, total=   2.6s
# [CV] kernel=rbf, C=100, gamma=0.01 ...................................
# [CV] .... kernel=rbf, C=100, gamma=0.01, score=0.970326, total=   2.6s
# [CV] kernel=rbf, C=100, gamma=0.01 ...................................
# [CV] .... kernel=rbf, C=100, gamma=0.01, score=0.976261, total=   2.6s
# [CV] kernel=rbf, C=100, gamma=0.001 ..................................
# [CV] ... kernel=rbf, C=100, gamma=0.001, score=0.841176, total=   4.3s
# [CV] kernel=rbf, C=100, gamma=0.001 ..................................
# [CV] ... kernel=rbf, C=100, gamma=0.001, score=0.863501, total=   4.4s
# [CV] kernel=rbf, C=100, gamma=0.001 ..................................
# [CV] ... kernel=rbf, C=100, gamma=0.001, score=0.839763, total=   4.4s
# [CV] kernel=rbf, C=100, gamma=0.0001 .................................
# [CV] .. kernel=rbf, C=100, gamma=0.0001, score=0.435294, total=   4.8s
# [CV] kernel=rbf, C=100, gamma=0.0001 .................................
# [CV] .. kernel=rbf, C=100, gamma=0.0001, score=0.436202, total=   4.9s
# [CV] kernel=rbf, C=100, gamma=0.0001 .................................
# [CV] .. kernel=rbf, C=100, gamma=0.0001, score=0.436202, total=   4.8s
# [CV] kernel=rbf, C=100, gamma=1e-05 ..................................
# [CV] ... kernel=rbf, C=100, gamma=1e-05, score=0.435294, total=   4.7s
# [CV] kernel=rbf, C=100, gamma=1e-05 ..................................
# [CV] ... kernel=rbf, C=100, gamma=1e-05, score=0.436202, total=   4.9s
# [CV] kernel=rbf, C=100, gamma=1e-05 ..................................
# [CV] ... kernel=rbf, C=100, gamma=1e-05, score=0.436202, total=   4.8s
# [CV] kernel=rbf, C=1000, gamma=0.01 ..................................
# [CV] ... kernel=rbf, C=1000, gamma=0.01, score=0.979412, total=   2.4s
# [CV] kernel=rbf, C=1000, gamma=0.01 ..................................
# [CV] ... kernel=rbf, C=1000, gamma=0.01, score=0.976261, total=   2.4s
# [CV] kernel=rbf, C=1000, gamma=0.01 ..................................
# [CV] ... kernel=rbf, C=1000, gamma=0.01, score=0.976261, total=   2.3s
# [CV] kernel=rbf, C=1000, gamma=0.001 .................................
# [CV] .. kernel=rbf, C=1000, gamma=0.001, score=0.976471, total=   2.6s
# [CV] kernel=rbf, C=1000, gamma=0.001 .................................
# [CV] .. kernel=rbf, C=1000, gamma=0.001, score=0.970326, total=   2.7s
# [CV] kernel=rbf, C=1000, gamma=0.001 .................................
# [CV] .. kernel=rbf, C=1000, gamma=0.001, score=0.976261, total=   2.6s
# [CV] kernel=rbf, C=1000, gamma=0.0001 ................................
# [CV] . kernel=rbf, C=1000, gamma=0.0001, score=0.841176, total=   4.6s
# [CV] kernel=rbf, C=1000, gamma=0.0001 ................................
# [CV] . kernel=rbf, C=1000, gamma=0.0001, score=0.863501, total=   4.5s
# [CV] kernel=rbf, C=1000, gamma=0.0001 ................................
# [CV] . kernel=rbf, C=1000, gamma=0.0001, score=0.839763, total=   4.3s
# [CV] kernel=rbf, C=1000, gamma=1e-05 .................................
# [CV] .. kernel=rbf, C=1000, gamma=1e-05, score=0.435294, total=   4.8s
# [CV] kernel=rbf, C=1000, gamma=1e-05 .................................
# [CV] .. kernel=rbf, C=1000, gamma=1e-05, score=0.436202, total=   4.9s
# [CV] kernel=rbf, C=1000, gamma=1e-05 .................................
# [CV] .. kernel=rbf, C=1000, gamma=1e-05, score=0.436202, total=   4.8s
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed:  4.6min finished
# Cannot save trained svm model to model.model
#
# Best parameters set:
# SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# Confusion matrix:
# Labels: 0,10,7
#
# [[ 60   0   0]
#  [  1 159   2]
#  [  1   3 113]]
#
# Classification report:
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98        60
#          10       0.98      0.98      0.98       162
#           7       0.98      0.97      0.97       117
#
# avg / total       0.98      0.98      0.98       339
# GridSearchCV(cv=3, error_score='raise',
#        estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False),
#        fit_params={}, iid=True, n_jobs=1,
#        param_grid=[{'kernel': ['linear'], 'C': [1, 10, 100, 1000]}, {'kernel': ['rbf'], 'C': [1, 10, 100, 1000], 'gamma': [0.01, 0.001, 0.0001, 1e-05]}],
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=3)

# %%
from bokeh.plotting import figure, output_notebook
output_notebook()
from bokeh.plotting import figure, show
from tsne import bh_sne
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="080bd5af-90e2-41ec-81a6-a6ef5c420065">Loading BokehJS ...</span>
#     </div>

# %%
vis_data = bh_sne(features_all, perplexity=30)
vis_x = vis_data[:,0]
vis_y = vis_data[:,1]

vis_data_0 = vis_data[labels_all=='0']
vis_data_7 = vis_data[labels_all=='7']
vis_data_10 = vis_data[labels_all=='10']

vis_data_0_x = vis_data_0[:,0]
vis_data_0_y = vis_data_0[:,1]
vis_data_7_x = vis_data_7[:,0]
vis_data_7_y = vis_data_7[:,1]
vis_data_10_x = vis_data_10[:,0]
vis_data_10_y = vis_data_10[:,1]

# %%
from bokeh.plotting import figure, output_file, show, ColumnDataSource
from bokeh.models import HoverTool


source1 = ColumnDataSource(
        data=dict(
            x=vis_data_0_x,
            y=vis_data_0_y,
            desc=sns_all[labels_all=='0'],
            imgs = images_all[labels_all=='0']

        )
    )

source2 = ColumnDataSource(
        data=dict(
            x=vis_data_7_x,
            y=vis_data_7_y,
            desc=sns_all[labels_all=='7'],
            imgs=images_all[labels_all=='7']
        )
    )

source3 = ColumnDataSource(
        data=dict(
            x=vis_data_10_x,
            y=vis_data_10_y,
            desc=sns_all[labels_all=='10'],
            imgs=images_all[labels_all=='10']
        )
    )



hover = HoverTool(
        tooltips="""
        <div>
            <div>
                <img
                    src="@imgs" height="80" alt="@imgs" width="80"
                    style="float: left; margin: 0px 15px 15px 0px;"
                    border="2"
                ></img>
            </div>
            <div>
                <span style="font-size: 17px; font-weight: bold;">@desc</span>
            </div>
        </div>
        """
    )

p = figure(plot_width=800, plot_height=800, tools=[hover],
           title="Mouse over the dots")

p.circle('x', 'y', size=20, alpha=0.5, color='green', source=source1)
p.circle('x', 'y', size=20, alpha=0.5, color='red', source=source2)
p.circle('x', 'y', size=20, alpha=0.5, color='blue', source=source3)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="93ddb128-e96a-4e60-8358-2eade5b73348"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#93ddb128-e96a-4e60-8358-2eade5b73348").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("93ddb128-e96a-4e60-8358-2eade5b73348");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '93ddb128-e96a-4e60-8358-2eade5b73348' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"70fd2c57-b76f-4da4-b252-9c925724f788":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"f2a3cd86-ee1e-47f0-9ecf-27b12cc17ac8","type":"HoverTool"}]},"id":"4557817e-8895-46ea-ac55-a051d935342d","type":"Toolbar"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"blue"},"line_alpha":{"value":0.5},"line_color":{"value":"blue"},"size":{"units":"screen","value":20},"x":{"field":"x"},"y":{"field":"y"}},"id":"25e302a2-8e8b-4515-b41a-c02f4b0a3cc4","type":"Circle"},{"attributes":{},"id":"bda9d0df-f373-425c-a44b-a3e15f799a5f","type":"ToolEvents"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":20},"x":{"field":"x"},"y":{"field":"y"}},"id":"bf287cdb-bc65-4f31-99b8-7c96f270797b","type":"Circle"},{"attributes":{"callback":null,"column_names":["imgs","y","desc","x"],"data":{"desc":["2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","2A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A","6A"],"imgs":["./reverse/MCEW-RF/2A/MCEW-RF_2A_c7/MCEW-RFRecombination_F3Y64760BGAH3RPA_2A_0.jpg","./reverse/MCEW-RF/2A/MCEW-RF_2A_c7/MCEW-RFRecombination_F3Y64760BGAH3RPA_2A_1.jpg","./reverse/MCEW-RF/2A/MCEW-RF_2A_c7/MCEW-RFRecombination_F3Y64760BGAH3RPA_2A_2.jpg","./reverse/MCEW-RF/2A/MCEW-RF_2A_c7/MCEW-RFRecombination_F3Y64760BGAH3RPA_2A_3.jpg","./reverse/MCEW-RF/2A/MCEW-RF_2A_c7/MCEW-RFRecombination_F3Y64760BGAH3RPA_2A_4.jpg","./reverse/MCEW-RF/2A/MCEW-RF_2A_c7/MCEW-RFRecombination_F3Y64760BGAH3RPA_2A_5.jpg","./reverse/MCEW-RF/2A/MCEW ...

# %%
for label_class in set(labels_all):
    sns_in_label = sns_all[labels_all == label_class]
    print 'the number of class {} is {}'.format(label_class, len(sns_in_label))
    print 'the number of S/Ns: is {}'.format(len(set(sns_in_label)))
    for sn in set(sns_in_label):
        print '\tthe number of S\N {}:{}'.format(sn, len(sns_all[(labels_all == label_class) & (sns_all == sn)]))
# Out:
# the number of class 10 is 604
# the number of S/Ns: is 2
# 	the number of S\N 6A:153
# 	the number of S\N 2A:451
# the number of class 7 is 490
# the number of S/Ns: is 2
# 	the number of S\N 6A:95
# 	the number of S\N 2A:395
# the number of class 0 is 259
# the number of S/Ns: is 2
# 	the number of S\N 6A:101
# 	the number of S\N 2A:158
