# %%
from defectlib import extract_features_from_defect, train_svm_classifier, plot_tsne
import numpy as np
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
features_all, labels_all, sns_all, images_all = extract_features_from_defect('./ben1214/L8009/')
# features_test, labels_test, sns_test, images_test = extract_features_from_defect('./defect_tensors_D10', comb=True)

#features_all = np.concatenate((features, features_test))
#labels_all = np.concatenate((labels, labels_test))
#sns_all = np.concatenate((sns, sns_test))
#images_all = np.concatenate((images, images_test))
# Out:
# there are 35 images inside L8009_7A_c0
# Processing ./ben1214/L8009/7A/L8009_7A_c0/F3Y64940NUFH3RPA 7AAAAAA_2.jpg...
# there are 24 images inside L8009_7A_c11
# Processing ./ben1214/L8009/7A/L8009_7A_c11/F3Y64951D0EGY4TA 7AAAAAA_2.jpg...
# there are 40 images inside L8009_7A_c4
# Processing ./ben1214/L8009/7A/L8009_7A_c4/F3Y65020248GY4RA 7AAAAAA_2.jpg...

# %%
plot_tsne(features_all, labels_all, images_all, perplexity=15, interactive=False)

# %%
train_svm_classifier(features_all, labels_all, sns_all, 'model.model', split=True)
# Out:
# train test split == True
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [CV] kernel=linear, C=1 ..............................................
# [CV] ............... kernel=linear, C=1, score=0.960000, total=   0.0s
# [CV] kernel=linear, C=1 ..............................................
# [CV] ............... kernel=linear, C=1, score=0.800000, total=   0.0s
# [CV] kernel=linear, C=1 ..............................................
# [CV] ............... kernel=linear, C=1, score=1.000000, total=   0.0s
# [CV] kernel=linear, C=10 .............................................
# [CV] .............. kernel=linear, C=10, score=0.960000, total=   0.0s
# [CV] kernel=linear, C=10 .............................................
# [CV] .............. kernel=linear, C=10, score=0.800000, total=   0.0s
# [CV] kernel=linear, C=10 .............................................
# [CV] .............. kernel=linear, C=10, score=1.000000, total=   0.0s
# [CV] kernel=linear, C=100 ............................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [CV] ............. kernel=linear, C=100, score=0.960000, total=   0.0s
# [CV] kernel=linear, C=100 ............................................
# [CV] ............. kernel=linear, C=100, score=0.800000, total=   0.0s
# [CV] kernel=linear, C=100 ............................................
# [CV] ............. kernel=linear, C=100, score=1.000000, total=   0.0s
# [CV] kernel=linear, C=1000 ...........................................
# [CV] ............ kernel=linear, C=1000, score=0.960000, total=   0.0s
# [CV] kernel=linear, C=1000 ...........................................
# [CV] ............ kernel=linear, C=1000, score=0.800000, total=   0.0s
# [CV] kernel=linear, C=1000 ...........................................
# [CV] ............ kernel=linear, C=1000, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=1, gamma=0.01 .....................................
# [CV] ...... kernel=rbf, C=1, gamma=0.01, score=0.760000, total=   0.0s
# [CV] kernel=rbf, C=1, gamma=0.01 .....................................
# [CV] ...... kernel=rbf, C=1, gamma=0.01, score=0.800000, total=   0.0s
# [CV] kernel=rbf, C=1, gamma=0.01 .....................................
# [CV] ...... kernel=rbf, C=1, gamma=0.01, score=0.791667, total=   0.0s
# [CV] kernel=rbf, C=1, gamma=0.001 ....................................
# [CV] ..... kernel=rbf, C=1, gamma=0.001, score=0.400000, total=   0.0s
# [CV] kernel=rbf, C=1, gamma=0.001 ....................................
# [CV] ..... kernel=rbf, C=1, gamma=0.001, score=0.400000, total=   0.0s
# [CV] kernel=rbf, C=1, gamma=0.001 ....................................
# [CV] ..... kernel=rbf, C=1, gamma=0.001, score=0.416667, total=   0.0s
# [CV] kernel=rbf, C=1, gamma=0.0001 ...................................
# [CV] .... kernel=rbf, C=1, gamma=0.0001, score=0.400000, total=   0.0s
# [CV] kernel=rbf, C=1, gamma=0.0001 ...................................
# [CV] .... kernel=rbf, C=1, gamma=0.0001, score=0.400000, total=   0.0s
# [CV] kernel=rbf, C=1, gamma=0.0001 ...................................
# [CV] .... kernel=rbf, C=1, gamma=0.0001, score=0.416667, total=   0.0s
# [CV] kernel=rbf, C=1, gamma=1e-05 ....................................
# [CV] ..... kernel=rbf, C=1, gamma=1e-05, score=0.400000, total=   0.0s
# [CV] kernel=rbf, C=1, gamma=1e-05 ....................................
# [CV] ..... kernel=rbf, C=1, gamma=1e-05, score=0.400000, total=   0.0s
# [CV] kernel=rbf, C=1, gamma=1e-05 ....................................
# [CV] ..... kernel=rbf, C=1, gamma=1e-05, score=0.416667, total=   0.0s
# [CV] kernel=rbf, C=10, gamma=0.01 ....................................
# [CV] ..... kernel=rbf, C=10, gamma=0.01, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=10, gamma=0.01 ....................................
# [CV] ..... kernel=rbf, C=10, gamma=0.01, score=0.760000, total=   0.0s
# [CV] kernel=rbf, C=10, gamma=0.01 ....................................
# [CV] ..... kernel=rbf, C=10, gamma=0.01, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=10, gamma=0.001 ...................................
# [CV] .... kernel=rbf, C=10, gamma=0.001, score=0.760000, total=   0.0s
# [CV] kernel=rbf, C=10, gamma=0.001 ...................................
# [CV] .... kernel=rbf, C=10, gamma=0.001, score=0.760000, total=   0.0s
# [CV] kernel=rbf, C=10, gamma=0.001 ...................................
# [CV] .... kernel=rbf, C=10, gamma=0.001, score=0.875000, total=   0.0s
# [CV] kernel=rbf, C=10, gamma=0.0001 ..................................
# [CV] ... kernel=rbf, C=10, gamma=0.0001, score=0.400000, total=   0.0s
# [CV] kernel=rbf, C=10, gamma=0.0001 ..................................
# [CV] ... kernel=rbf, C=10, gamma=0.0001, score=0.400000, total=   0.0s
# [CV] kernel=rbf, C=10, gamma=0.0001 ..................................
# [CV] ... kernel=rbf, C=10, gamma=0.0001, score=0.416667, total=   0.0s
# [CV] kernel=rbf, C=10, gamma=1e-05 ...................................
# [CV] .... kernel=rbf, C=10, gamma=1e-05, score=0.400000, total=   0.0s
# [CV] kernel=rbf, C=10, gamma=1e-05 ...................................
# [CV] .... kernel=rbf, C=10, gamma=1e-05, score=0.400000, total=   0.0s
# [CV] kernel=rbf, C=10, gamma=1e-05 ...................................
# [CV] .... kernel=rbf, C=10, gamma=1e-05, score=0.416667, total=   0.0s
# [CV] kernel=rbf, C=100, gamma=0.01 ...................................
# [CV] .... kernel=rbf, C=100, gamma=0.01, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=100, gamma=0.01 ...................................
# [CV] .... kernel=rbf, C=100, gamma=0.01, score=0.760000, total=   0.0s
# [CV] kernel=rbf, C=100, gamma=0.01 ...................................
# [CV] .... kernel=rbf, C=100, gamma=0.01, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=100, gamma=0.001 ..................................
# [CV] ... kernel=rbf, C=100, gamma=0.001, score=0.960000, total=   0.0s
# [CV] kernel=rbf, C=100, gamma=0.001 ..................................
# [CV] ... kernel=rbf, C=100, gamma=0.001, score=0.800000, total=   0.0s
# [CV] kernel=rbf, C=100, gamma=0.001 ..................................
# [CV] ... kernel=rbf, C=100, gamma=0.001, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=100, gamma=0.0001 .................................
# [CV] .. kernel=rbf, C=100, gamma=0.0001, score=0.760000, total=   0.0s
# [CV] kernel=rbf, C=100, gamma=0.0001 .................................
# [CV] .. kernel=rbf, C=100, gamma=0.0001, score=0.760000, total=   0.0s
# [CV] kernel=rbf, C=100, gamma=0.0001 .................................
# [CV] .. kernel=rbf, C=100, gamma=0.0001, score=0.875000, total=   0.0s
# [CV] kernel=rbf, C=100, gamma=1e-05 ..................................
# [CV] ... kernel=rbf, C=100, gamma=1e-05, score=0.400000, total=   0.0s
# [CV] kernel=rbf, C=100, gamma=1e-05 ..................................
# [CV] ... kernel=rbf, C=100, gamma=1e-05, score=0.400000, total=   0.0s
# [CV] kernel=rbf, C=100, gamma=1e-05 ..................................
# [CV] ... kernel=rbf, C=100, gamma=1e-05, score=0.416667, total=   0.0s
# [CV] kernel=rbf, C=1000, gamma=0.01 ..................................
# [CV] ... kernel=rbf, C=1000, gamma=0.01, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=1000, gamma=0.01 ..................................
# [CV] ... kernel=rbf, C=1000, gamma=0.01, score=0.760000, total=   0.0s
# [CV] kernel=rbf, C=1000, gamma=0.01 ..................................
# [CV] ... kernel=rbf, C=1000, gamma=0.01, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=1000, gamma=0.001 .................................
# [CV] .. kernel=rbf, C=1000, gamma=0.001, score=0.960000, total=   0.0s
# [CV] kernel=rbf, C=1000, gamma=0.001 .................................
# [CV] .. kernel=rbf, C=1000, gamma=0.001, score=0.800000, total=   0.0s
# [CV] kernel=rbf, C=1000, gamma=0.001 .................................
# [CV] .. kernel=rbf, C=1000, gamma=0.001, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=1000, gamma=0.0001 ................................
# [CV] . kernel=rbf, C=1000, gamma=0.0001, score=0.960000, total=   0.0s
# [CV] kernel=rbf, C=1000, gamma=0.0001 ................................
# [CV] . kernel=rbf, C=1000, gamma=0.0001, score=0.800000, total=   0.0s
# [CV] kernel=rbf, C=1000, gamma=0.0001 ................................
# [CV] . kernel=rbf, C=1000, gamma=0.0001, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=1000, gamma=1e-05 .................................
# [CV] .. kernel=rbf, C=1000, gamma=1e-05, score=0.760000, total=   0.0s
# [CV] kernel=rbf, C=1000, gamma=1e-05 .................................
# [CV] .. kernel=rbf, C=1000, gamma=1e-05, score=0.760000, total=   0.0s
# [CV] kernel=rbf, C=1000, gamma=1e-05 .................................
# [CV] .. kernel=rbf, C=1000, gamma=1e-05, score=0.875000, total=   0.0s
# Cannot save trained svm model to model.model
#
# Best parameters set:
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# Confusion matrix:
# Labels: 0,11,4
#
# [[ 8  0  0]
#  [ 0  7  0]
#  [ 0  0 10]]
#
# Classification report:
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00         8
#          11       1.00      1.00      1.00         7
#           4       1.00      1.00      1.00        10
#
# avg / total       1.00      1.00      1.00        25
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed:    2.1s finished
# GridSearchCV(cv=3, error_score='raise',
#        estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False),
#        fit_params={}, iid=True, n_jobs=1,
#        param_grid=[{'kernel': ['linear'], 'C': [1, 10, 100, 1000]}, {'kernel': ['rbf'], 'C': [1, 10, 100, 1000], 'gamma': [0.01, 0.001, 0.0001, 1e-05]}],
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=3)

# %%
from bokeh.plotting import figure, output_notebook
output_notebook()
from bokeh.plotting import figure, show
from tsne import bh_sne
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3169ef78-298b-47b8-8fc1-6f02b8582aa6">Loading BokehJS ...</span>
#     </div>

# %%
vis_data = bh_sne(features_all, perplexity=30)
vis_x = vis_data[:,0]
vis_y = vis_data[:,1]

vis_data_0 = vis_data[labels_all=='0']
vis_data_4 = vis_data[labels_all=='4']
vis_data_11 = vis_data[labels_all=='11']

vis_data_0_x = vis_data_0[:,0]
vis_data_0_y = vis_data_0[:,1]
vis_data_4_x = vis_data_4[:,0]
vis_data_4_y = vis_data_4[:,1]
vis_data_11_x = vis_data_11[:,0]
vis_data_11_y = vis_data_11[:,1]

# %%
from bokeh.plotting import figure, output_file, show, ColumnDataSource
from bokeh.models import HoverTool


source1 = ColumnDataSource(
        data=dict(
            x=vis_data_0_x,
            y=vis_data_0_y,
            desc=sns_all[labels_all=='0'],
            imgs = images_all[labels_all=='0']

        )
    )


source2 = ColumnDataSource(
        data=dict(
            x=vis_data_4_x,
            y=vis_data_4_y,
            desc=sns_all[labels_all=='4'],
            imgs=images_all[labels_all=='4']
        )
    )

source3 = ColumnDataSource(
        data=dict(
            x=vis_data_11_x,
            y=vis_data_11_y,
            desc=sns_all[labels_all=='11'],
            imgs=images_all[labels_all=='11']
        )
    )


hover = HoverTool(
        tooltips="""
        <div>
            <div>
                <img
                    src="@imgs" height="50" alt="@imgs" width="50"
                    style="float: left; margin: 0px 15px 15px 0px;"
                    border="2"
                ></img>
            </div>
            <div>
                <span style="font-size: 17px; font-weight: bold;">@desc</span>
            </div>
        </div>
        """
    )

p = figure(plot_width=400, plot_height=400, tools=[hover],
           title="Mouse over the dots")

p.circle('x', 'y', size=20, alpha=0.5, color='green', source=source1)
p.circle('x', 'y', size=20, alpha=0.5, color='red', source=source2)
p.circle('x', 'y', size=20, alpha=0.5, color='blue', source=source3)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="a96aa55a-eb98-4a48-9427-249b110fb84a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#a96aa55a-eb98-4a48-9427-249b110fb84a").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a96aa55a-eb98-4a48-9427-249b110fb84a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a96aa55a-eb98-4a48-9427-249b110fb84a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"00a727d5-42bf-4650-afed-8e6c9693521d":{"roots":{"references":[{"attributes":{"callback":null},"id":"980f2a9d-29ca-49f7-80d1-406e21e57688","type":"DataRange1d"},{"attributes":{"plot":{"id":"abd50cb8-489c-422f-8bf3-cc68223a0432","subtype":"Figure","type":"Plot"},"ticker":{"id":"09429887-24f6-406b-a0c3-0365c28ed1a7","type":"BasicTicker"}},"id":"4724fcf6-3b8f-43b8-a954-25896440431e","type":"Grid"},{"attributes":{},"id":"09429887-24f6-406b-a0c3-0365c28ed1a7","type":"BasicTicker"},{"attributes":{},"id":"882b9cb9-a78b-49b1-88a1-77a647f87516","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"green"},"line_alpha":{"value":0.5},"line_color":{"value":"green"},"size":{"units":"screen","value":20},"x":{"field":"x"},"y":{"field":"y"}},"id":"2d002da1-3c60-43c0-8f2d-d28ecc91827e","type":"Circle"},{"attributes":{"callback":null,"column_names":["imgs","y","desc","x"],"data":{"desc":["F3Y64940NUFH3RPA","F3Y64950033H3RPA","F3Y64950037H3RPA","F3Y649500C1H3RPA","F3Y649500P8H3RPA","F3Y649500P8H3RPA","F3Y649500SHH3RPA","F3Y649500SHH3RPA","F3Y6495014NH3RPA","F3Y6495015AH3RPA","F3Y6495015AH3RPA","F3Y649501FKH3RPA","F3Y649501JVH3RPA","F3Y649501JYH3RPA","F3Y649501QGH3RPA","F3Y649501XRH3RPA","F3Y649501XRH3RPA","F3Y649503XLH3RPA","F3Y649503XLH3RPA","F3Y649505FSH3RPA","L8009","L8009","L8009","L8009","L8009","L8009","L8009","L8009","L8009","L8009","L8009","L8009","L8009","L8009","L8009"],"imgs":["./ben1214/L8009/7A/L8009_7A_c0/F3Y64940NUFH3RPA 7AAAAAA_2.jpg","./ben1214/L8009/7A/L8009_7A_c0/F3Y64950033H3RPA 7AAAAAA_2.jpg","./ben1214/L8009/7A/L8009_7A_c0/F3Y64950037H3RPA 7AAAAAA_2.jpg","./ben1214/L8009/7A/L8009_7A_c0/F3Y649500C1H3RPA 7AAAAAA_2.jpg","./ben1214/L8009/7A/L8009_7A_c0/F3Y649500P8H3RPA 7AAAAAA_1.jpg","./ben1214/L8009/7A/L8009_7A_c0/F3Y649500P8H3RPA 7AAAAAA_2.jpg","./ben1214/L8009/7A/L8009_7A_c0/F3Y649500SHH3RPA 7AAAAAA_1.jpg","./ben1214/L8009/7A/L8009_7A_c0/F3Y649500SHH3RPA 7AAAAAA_2.jpg","./ben1214/L8009/7A/L8009_7A_c0/F3Y6495014NH3RPA 7AAAAAA_2.jpg","./ben1214/L8009/7A/L8009_7A_c0/F3Y6495015AH3RPA 7AAAAAA_1.jpg","./ben1214/L8009/7A/L8009_7A_c0/F3Y6495015AH3RPA 7AAAAAA_2.jpg","./ben1214/L8009/7A/L8009_7A_c0/F3Y649501FKH3RPA 7AAAAAA_2.jpg","./ben1214/L8009/7A/L8009_7A_c0/F3Y649501JVH3RPA 7AAAAAA_2.jpg","./ben1214/L8009/7A/L8009_7A_c0/F3Y649501JYH3RPA 7AAAAAA_2.jpg","./ben1214/L8009/7A/L8009_7A_c0/F3Y649501QGH3RPA 7AAAAAA_2.jpg","./ben1214/L8009/7A/L8009_7A_c0/F3Y649501XRH3RPA 7AAAAAA_1.jpg","./ben1214/L8009/7A/L8009_7A_c0/F3Y649501XRH3RPA 7AAAAAA_2.jpg","./ben1214/L8009/7A/L8009_7A_c0/F3Y649503XLH3RPA 7AAAAAA_1.jpg","./ben1214/L8009/7A/L8009_7A_c0/F3Y649503XLH3RPA 7AAAAAA_2.jpg","./ben1214/L8009/7A/L8009_7A_c0/F3Y649505FSH3RPA 7AAAAAA_2.jpg","./ben1214/L8009/7A/L8009_7A_c0/L8009_Recombination_F3Y64940NUFH3RPA_7A_0.jpg","./ben1214/L8009/7A/L8009_7A_c0/L8009_Recombination_F3Y64950033H3RPA_7A_0.jpg","./ben1214/L8009/7A/L8009_7A_c0/L8009_Recombination_F3Y64950037H3RPA_7A_0.jpg","./ben1214/L8009/7A/L8009_7A_c0/L8009_Recombination_F3Y649500C1H3RPA_7A_0.jpg","./ben1214/L8009/7A/L8009_7A_c0/L8009_Recombination_F3Y649500P8H3RPA_7A_0.jpg","./ben1214/L8009/7A/L8009_7A_c0/L8009_Recombination_F3Y649500SHH3RPA_7A_0.jpg","./ben1214/L8009/7A/L8009_7A_c0/L8009_Recombination_F3Y6495014NH3RPA_7A_0.jpg","./ben1214/L8009/7A/L8009_7A_c0/L8009_Recombination_F3Y6495015AH3RPA_7A_0.jpg","./ben1214/L8009/7A/L8009_7A_c0/L8009_Recombination_F3Y649501FKH3RPA_7A_0.jpg","./ben1214/L8009/7A/L8009_7A_c0/L8009_Recombination_F3Y649501JVH3RPA_7A_0.jpg","./ben1214/L8009/7A/L8009_7A_c0/L8009_Recombination_F3Y649501JYH3RPA_7A_0.jpg","./ben1214/L8009/7A/L8009_7A_c0/L8009_Recombination_F3Y649501QGH3RPA_7A_0.jpg","./ben1214/L8009/7A/L8009_7A_c0/L8009_Recombination_F3Y649501XRH3RPA_7A_0.jpg","./ben1214/L8009/7A/L8009_7A_c0/L8009_Recombination_F3Y649503XLH3RPA_7A_0.jpg","./ben1214/L8009/7A/L8009_7A_c0/L8009_Recombination_F3Y649505FSH3RPA_7A_0.jpg"],"x":[-2.914358343706562,-5.985138611843336,-1.5603732545262772,1.14996518 ...

# %%
for label_class in set(labels_all):
    sns_in_label = sns_all[labels_all == label_class]
    print 'the number of class {} is {}'.format(label_class, len(sns_in_label))
    print 'the number of S/Ns: is {}'.format(len(set(sns_in_label)))
    for sn in set(sns_in_label):
        print '\tthe number of S\N {}:{}'.format(sn, len(sns_all[(labels_all == label_class) & (sns_all == sn)]))
# Out:
# the number of class 11 is 24
# the number of S/Ns: is 20
# 	the number of S\N F3Y650505JLGY4VC:1
# 	the number of S\N F3Y65050KJ1GY4VC:1
# 	the number of S\N F3Y65050L95GY4VC:1
# 	the number of S\N F3Y65050K2NGY4VC:2
# 	the number of S\N F3Y65050E5JGY4VC:1
# 	the number of S\N F3Y650512A3GY4TB:1
# 	the number of S\N F3Y65050HJTGY4VC:1
# 	the number of S\N F3Y65050KTSGY4VC:2
# 	the number of S\N F3Y65050L94GY4VC:2
# 	the number of S\N F3Y65050HJUGY4VC:1
# 	the number of S\N F3Y65050HJVGY4VC:1
# 	the number of S\N F3Y65030GEGGY4TA:2
# 	the number of S\N F3Y650511CQGY4TB:1
# 	the number of S\N F3Y650506U1GY4VC:1
# 	the number of S\N F3Y65050KTTGY4VC:1
# 	the number of S\N F3Y64951D0EGY4TA:1
# 	the number of S\N F3Y65010KASGY4RA:1
# 	the number of S\N F3Y65041DQKGY4TA:1
# 	the number of S\N F3Y650505PBGY4VC:1
# 	the number of S\N F3Y65050L92GY4VC:1
# the number of class 0 is 35
# the number of S/Ns: is 16
# 	the number of S\N F3Y64940NUFH3RPA:1
# 	the number of S\N F3Y649500C1H3RPA:1
# 	the number of S\N F3Y649501XRH3RPA:2
# 	the number of S\N F3Y649501JVH3RPA:1
# 	the number of S\N F3Y649505FSH3RPA:1
# 	the number of S\N F3Y649501FKH3RPA:1
# 	the number of S\N F3Y64950033H3RPA:1
# 	the number of S\N F3Y6495015AH3RPA:2
# 	the number of S\N F3Y64950037H3RPA:1
# 	the number of S\N L8009:15
# 	the number of S\N F3Y649501QGH3RPA:1
# 	the number of S\N F3Y649500P8H3RPA:2
# 	the number of S\N F3Y649503XLH3RPA:2
# 	the number of S\N F3Y649501JYH3RPA:1
# 	the number of S\N F3Y6495014NH3RPA:1
# 	the number of S\N F3Y649500SHH3RPA:2
# the number of class 4 is 40
# the number of S/Ns: is 29
# 	the number of S\N F3Y65030F4EGY4RA:1
# 	the number of S\N F3Y650403XKGY4RA:2
# 	the number of S\N F3Y65041B7GGY4TA:1
# 	the number of S\N F3Y65040QV2GY4RA:2
# 	the number of S\N F3Y65041B7EGY4TA:2
# 	the number of S\N F3Y65030KB0GY4RA:2
# 	the number of S\N F3Y65030KMJGY4RA:1
# 	the number of S\N F3Y65020248GY4RA:1
# 	the number of S\N F3Y65041BHEGY4TA:1
# 	the number of S\N F3Y65041B7FGY4TA:1
# 	the number of S\N F3Y650506QSGY2WC:1
# 	the number of S\N F3Y650600TGGY2VB:2
# 	the number of S\N F3Y65041D64GY4TA:1
# 	the number of S\N F3Y65030FDRGY4RA:1
# 	the number of S\N F3Y65050MRLGY4RB:2
# 	the number of S\N F3Y650409ADGY2VA:2
# 	the number of S\N F3Y650402NNGY2VA:1
# 	the number of S\N F3Y65041D63GY4TA:1
# 	the number of S\N F3Y65041CF4GY4TA:1
# 	the number of S\N F3Y65041BHBGY4TA:1
# 	the number of S\N F3Y65041BHCGY4TA:1
# 	the number of S\N F3Y65050LXFGY4RB:2
# 	the number of S\N F3Y650607NMH3RNB:1
# 	the number of S\N F3Y650409ACGY2VA:2
# 	the number of S\N F3Y650602XYGY2VB:2
# 	the number of S\N F3Y65041CF3GY4TA:1
# 	the number of S\N F3Y65020F4FGY4RA:1
# 	the number of S\N F3Y650607NPH3RNB:1
# 	the number of S\N F3Y650600TEGY2VB:2
