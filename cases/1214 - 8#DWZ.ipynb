# %%
from defectlib import extract_features_from_defect, train_svm_classifier, plot_tsne
import numpy as np
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
features, labels, sns, images = extract_features_from_defect('./reverse/8#DWZ/', comb=True)
features_test, labels_test, sns_test, images_test = extract_features_from_defect('./defect_tensors_D10/8#DWZ/', comb=True)

features_all = np.concatenate((features, features_test))
labels_all = np.concatenate((labels, labels_test))
sns_all = np.concatenate((sns, sns_test))
images_all = np.concatenate((images, images_test))
# Out:
# there are 114 images inside 8#DWZ_2A_c3
# Processing ./reverse/8#DWZ/2A/8#DWZ_2A_c3/8#DWZ_Recombination_F3Y64770147H3RPA_2A_0.jpg...
# Processing ./reverse/8#DWZ/2A/8#DWZ_2A_c3/8#DWZ_Recombination_F3Y65050FP1H3RQC_2A_1.jpg...
# there are 15 images inside 8#DWZ_6A_c3
# Processing ./reverse/8#DWZ/6A/8#DWZ_6A_c3/8#DWZ_Recombination_F3Y64770147H3RPA_6A_0.jpg...
# there are 53 images inside 8#DWZ_2A_c0
# Processing ./defect_tensors_D10/8#DWZ/2A/8#DWZ_2A_c0/8#DWZ_Recombination_0_2A_0.jpg...
# there are 27 images inside 8#DWZ_2A_c3
# Processing ./defect_tensors_D10/8#DWZ/2A/8#DWZ_2A_c3/8#DWZ_Recombination_F3Y649409EAGY4VB_2A_0.jpg...
# there are 11 images inside 8#DWZ_6A_c0
# Processing ./defect_tensors_D10/8#DWZ/6A/8#DWZ_6A_c0/8#DWZ_Recombination_0_6A_0.jpg...
# there are 6 images inside 8#DWZ_6A_c3
# Processing ./defect_tensors_D10/8#DWZ/6A/8#DWZ_6A_c3/8#DWZ_Recombination_F3Y649409EAGY4VB_6A_0.jpg...

# %%
plot_tsne(features_all, labels_all, images_all, perplexity=30, interactive=False)

# %%
train_svm_classifier(features_all, labels_all, sns_all, 'model.model', split=True)
# Out:
# train test split == True
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [CV] kernel=linear, C=1 ..............................................
# [CV] ............... kernel=linear, C=1, score=0.947368, total=   0.0s
# [CV] kernel=linear, C=1 ..............................................
# [CV] ............... kernel=linear, C=1, score=1.000000, total=   0.0s
# [CV] kernel=linear, C=1 ..............................................
# [CV] ............... kernel=linear, C=1, score=1.000000, total=   0.0s
# [CV] kernel=linear, C=10 .............................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [CV] .............. kernel=linear, C=10, score=0.947368, total=   0.0s
# [CV] kernel=linear, C=10 .............................................
# [CV] .............. kernel=linear, C=10, score=1.000000, total=   0.0s
# [CV] kernel=linear, C=10 .............................................
# [CV] .............. kernel=linear, C=10, score=1.000000, total=   0.0s
# [CV] kernel=linear, C=100 ............................................
# [CV] ............. kernel=linear, C=100, score=0.947368, total=   0.0s
# [CV] kernel=linear, C=100 ............................................
# [CV] ............. kernel=linear, C=100, score=1.000000, total=   0.0s
# [CV] kernel=linear, C=100 ............................................
# [CV] ............. kernel=linear, C=100, score=1.000000, total=   0.0s
# [CV] kernel=linear, C=1000 ...........................................
# [CV] ............ kernel=linear, C=1000, score=0.947368, total=   0.0s
# [CV] kernel=linear, C=1000 ...........................................
# [CV] ............ kernel=linear, C=1000, score=1.000000, total=   0.0s
# [CV] kernel=linear, C=1000 ...........................................
# [CV] ............ kernel=linear, C=1000, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=1, gamma=0.01 .....................................
# [CV] ...... kernel=rbf, C=1, gamma=0.01, score=0.877193, total=   0.1s
# [CV] kernel=rbf, C=1, gamma=0.01 .....................................
# [CV] ...... kernel=rbf, C=1, gamma=0.01, score=1.000000, total=   0.1s
# [CV] kernel=rbf, C=1, gamma=0.01 .....................................
# [CV] ...... kernel=rbf, C=1, gamma=0.01, score=0.928571, total=   0.1s
# [CV] kernel=rbf, C=1, gamma=0.001 ....................................
# [CV] ..... kernel=rbf, C=1, gamma=0.001, score=0.701754, total=   0.1s
# [CV] kernel=rbf, C=1, gamma=0.001 ....................................
# [CV] ..... kernel=rbf, C=1, gamma=0.001, score=0.714286, total=   0.1s
# [CV] kernel=rbf, C=1, gamma=0.001 ....................................
# [CV] ..... kernel=rbf, C=1, gamma=0.001, score=0.714286, total=   0.1s
# [CV] kernel=rbf, C=1, gamma=0.0001 ...................................
# [CV] .... kernel=rbf, C=1, gamma=0.0001, score=0.701754, total=   0.1s
# [CV] kernel=rbf, C=1, gamma=0.0001 ...................................
# [CV] .... kernel=rbf, C=1, gamma=0.0001, score=0.714286, total=   0.1s
# [CV] kernel=rbf, C=1, gamma=0.0001 ...................................
# [CV] .... kernel=rbf, C=1, gamma=0.0001, score=0.714286, total=   0.1s
# [CV] kernel=rbf, C=1, gamma=1e-05 ....................................
# [CV] ..... kernel=rbf, C=1, gamma=1e-05, score=0.701754, total=   0.1s
# [CV] kernel=rbf, C=1, gamma=1e-05 ....................................
# [CV] ..... kernel=rbf, C=1, gamma=1e-05, score=0.714286, total=   0.1s
# [CV] kernel=rbf, C=1, gamma=1e-05 ....................................
# [CV] ..... kernel=rbf, C=1, gamma=1e-05, score=0.714286, total=   0.1s
# [CV] kernel=rbf, C=10, gamma=0.01 ....................................
# [CV] ..... kernel=rbf, C=10, gamma=0.01, score=0.947368, total=   0.0s
# [CV] kernel=rbf, C=10, gamma=0.01 ....................................
# [CV] ..... kernel=rbf, C=10, gamma=0.01, score=1.000000, total=   0.1s
# [CV] kernel=rbf, C=10, gamma=0.01 ....................................
# [CV] ..... kernel=rbf, C=10, gamma=0.01, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=10, gamma=0.001 ...................................
# [CV] .... kernel=rbf, C=10, gamma=0.001, score=0.877193, total=   0.1s
# [CV] kernel=rbf, C=10, gamma=0.001 ...................................
# [CV] .... kernel=rbf, C=10, gamma=0.001, score=1.000000, total=   0.1s
# [CV] kernel=rbf, C=10, gamma=0.001 ...................................
# [CV] .... kernel=rbf, C=10, gamma=0.001, score=0.910714, total=   0.1s
# [CV] kernel=rbf, C=10, gamma=0.0001 ..................................
# [CV] ... kernel=rbf, C=10, gamma=0.0001, score=0.701754, total=   0.1s
# [CV] kernel=rbf, C=10, gamma=0.0001 ..................................
# [CV] ... kernel=rbf, C=10, gamma=0.0001, score=0.714286, total=   0.1s
# [CV] kernel=rbf, C=10, gamma=0.0001 ..................................
# [CV] ... kernel=rbf, C=10, gamma=0.0001, score=0.714286, total=   0.1s
# [CV] kernel=rbf, C=10, gamma=1e-05 ...................................
# [CV] .... kernel=rbf, C=10, gamma=1e-05, score=0.701754, total=   0.1s
# [CV] kernel=rbf, C=10, gamma=1e-05 ...................................
# [CV] .... kernel=rbf, C=10, gamma=1e-05, score=0.714286, total=   0.1s
# [CV] kernel=rbf, C=10, gamma=1e-05 ...................................
# [CV] .... kernel=rbf, C=10, gamma=1e-05, score=0.714286, total=   0.1s
# [CV] kernel=rbf, C=100, gamma=0.01 ...................................
# [CV] .... kernel=rbf, C=100, gamma=0.01, score=0.947368, total=   0.0s
# [CV] kernel=rbf, C=100, gamma=0.01 ...................................
# [CV] .... kernel=rbf, C=100, gamma=0.01, score=1.000000, total=   0.1s
# [CV] kernel=rbf, C=100, gamma=0.01 ...................................
# [CV] .... kernel=rbf, C=100, gamma=0.01, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=100, gamma=0.001 ..................................
# [CV] ... kernel=rbf, C=100, gamma=0.001, score=0.947368, total=   0.0s
# [CV] kernel=rbf, C=100, gamma=0.001 ..................................
# [CV] ... kernel=rbf, C=100, gamma=0.001, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=100, gamma=0.001 ..................................
# [CV] ... kernel=rbf, C=100, gamma=0.001, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=100, gamma=0.0001 .................................
# [CV] .. kernel=rbf, C=100, gamma=0.0001, score=0.877193, total=   0.1s
# [CV] kernel=rbf, C=100, gamma=0.0001 .................................
# [CV] .. kernel=rbf, C=100, gamma=0.0001, score=1.000000, total=   0.1s
# [CV] kernel=rbf, C=100, gamma=0.0001 .................................
# [CV] .. kernel=rbf, C=100, gamma=0.0001, score=0.910714, total=   0.1s
# [CV] kernel=rbf, C=100, gamma=1e-05 ..................................
# [CV] ... kernel=rbf, C=100, gamma=1e-05, score=0.701754, total=   0.1s
# [CV] kernel=rbf, C=100, gamma=1e-05 ..................................
# [CV] ... kernel=rbf, C=100, gamma=1e-05, score=0.714286, total=   0.1s
# [CV] kernel=rbf, C=100, gamma=1e-05 ..................................
# [CV] ... kernel=rbf, C=100, gamma=1e-05, score=0.714286, total=   0.1s
# [CV] kernel=rbf, C=1000, gamma=0.01 ..................................
# [CV] ... kernel=rbf, C=1000, gamma=0.01, score=0.947368, total=   0.1s
# [CV] kernel=rbf, C=1000, gamma=0.01 ..................................
# [CV] ... kernel=rbf, C=1000, gamma=0.01, score=1.000000, total=   0.1s
# [CV] kernel=rbf, C=1000, gamma=0.01 ..................................
# [CV] ... kernel=rbf, C=1000, gamma=0.01, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=1000, gamma=0.001 .................................
# [CV] .. kernel=rbf, C=1000, gamma=0.001, score=0.947368, total=   0.0s
# [CV] kernel=rbf, C=1000, gamma=0.001 .................................
# [CV] .. kernel=rbf, C=1000, gamma=0.001, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=1000, gamma=0.001 .................................
# [CV] .. kernel=rbf, C=1000, gamma=0.001, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=1000, gamma=0.0001 ................................
# [CV] . kernel=rbf, C=1000, gamma=0.0001, score=0.947368, total=   0.0s
# [CV] kernel=rbf, C=1000, gamma=0.0001 ................................
# [CV] . kernel=rbf, C=1000, gamma=0.0001, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=1000, gamma=0.0001 ................................
# [CV] . kernel=rbf, C=1000, gamma=0.0001, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=1000, gamma=1e-05 .................................
# [CV] .. kernel=rbf, C=1000, gamma=1e-05, score=0.877193, total=   0.1s
# [CV] kernel=rbf, C=1000, gamma=1e-05 .................................
# [CV] .. kernel=rbf, C=1000, gamma=1e-05, score=1.000000, total=   0.1s
# [CV] kernel=rbf, C=1000, gamma=1e-05 .................................
# [CV] .. kernel=rbf, C=1000, gamma=1e-05, score=0.910714, total=   0.1s
# Cannot save trained svm model to model.model
#
# Best parameters set:
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# Confusion matrix:
# Labels: 0,3
#
# [[15  0]
#  [ 2 40]]
#
# Classification report:
#              precision    recall  f1-score   support
#
#           0       0.88      1.00      0.94        15
#           3       1.00      0.95      0.98        42
#
# avg / total       0.97      0.96      0.97        57
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed:    4.4s finished
# GridSearchCV(cv=3, error_score='raise',
#        estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False),
#        fit_params={}, iid=True, n_jobs=1,
#        param_grid=[{'kernel': ['linear'], 'C': [1, 10, 100, 1000]}, {'kernel': ['rbf'], 'C': [1, 10, 100, 1000], 'gamma': [0.01, 0.001, 0.0001, 1e-05]}],
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=3)

# %%
from bokeh.plotting import figure, output_notebook
output_notebook()
from bokeh.plotting import figure, show
from tsne import bh_sne
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d537eb6a-5b70-453e-81af-4a48532c190e">Loading BokehJS ...</span>
#     </div>

# %%
vis_data = bh_sne(features_all, perplexity=30)
vis_x = vis_data[:,0]
vis_y = vis_data[:,1]

vis_data_0 = vis_data[labels_all=='0']
vis_data_3 = vis_data[labels_all=='3']

vis_data_0_x = vis_data_0[:,0]
vis_data_0_y = vis_data_0[:,1]
vis_data_3_x = vis_data_3[:,0]
vis_data_3_y = vis_data_3[:,1]

# %%
from bokeh.plotting import figure, output_file, show, ColumnDataSource
from bokeh.models import HoverTool


source1 = ColumnDataSource(
        data=dict(
            x=vis_data_0_x,
            y=vis_data_0_y,
            desc=sns_all[labels_all=='0'],
            imgs = images_all[labels_all=='0']

        )
    )

source2 = ColumnDataSource(
        data=dict(
            x=vis_data_3_x,
            y=vis_data_3_y,
            desc=sns_all[labels_all=='3'],
            imgs=images_all[labels_all=='3']
        )
    )





hover = HoverTool(
        tooltips="""
        <div>
            <div>
                <img
                    src="@imgs" height="80" alt="@imgs" width="80"
                    style="float: left; margin: 0px 15px 15px 0px;"
                    border="2"
                ></img>
            </div>
            <div>
                <span style="font-size: 17px; font-weight: bold;">@desc</span>
            </div>
        </div>
        """
    )

p = figure(plot_width=800, plot_height=800, tools=[hover],
           title="Mouse over the dots")

p.circle('x', 'y', size=20, alpha=0.5, color='green', source=source1)
p.circle('x', 'y', size=20, alpha=0.5, color='red', source=source2)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="936fc4e3-9ffa-44b1-9f60-8c8acef84e4c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#936fc4e3-9ffa-44b1-9f60-8c8acef84e4c").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("936fc4e3-9ffa-44b1-9f60-8c8acef84e4c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '936fc4e3-9ffa-44b1-9f60-8c8acef84e4c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"6890a82c-c009-457a-9a1f-26668a72ae7e":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":20},"x":{"field":"x"},"y":{"field":"y"}},"id":"2b818b24-91ae-411f-bb6e-135958f0437f","type":"Circle"},{"attributes":{},"id":"8bcdbbfd-9426-4661-89d6-2446f3ec4657","type":"BasicTicker"},{"attributes":{},"id":"b7cedabf-e155-43fd-a325-d0fb775ea131","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":20},"x":{"field":"x"},"y":{"field":"y"}},"id":"cef8e6f9-c452-47c3-a755-9ab2b070dc15","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"red"},"line_alpha":{"value":0.5},"line_color":{"value":"red"},"size":{"units":"screen","value":20},"x":{"field":"x"},"y":{"field":"y"}},"id":"405a1e59-1541-455a-b138-0453f3e5aa7f","type":"Circle"},{"attributes":{"callback":null,"plot":{"id":"737bf7cf-d926-4f0e-aa9d-d6287a81999c","subtype":"Figure","type":"Plot"},"tooltips":"\n        <div>\n            <div>\n                <img\n                    src=\"@imgs\" height=\"80\" alt=\"@imgs\" width=\"80\"\n                    style=\"float: left; margin: 0px 15px 15px 0px;\"\n                    border=\"2\"\n                ></img>\n            </div>\n            <div>\n                <span style=\"font-size: 17px; font-weight: bold;\">@desc</span>\n            </div>\n        </div>\n        "},"id":"4b7dc2ba-4372-4b6d-bc7f-480f1c988e82","type":"HoverTool"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"green"},"line_alpha":{"value":0.5},"line_color":{"value":"green"},"size":{"units":"screen","value":20},"x":{"field":"x"},"y":{"field":"y"}},"id":"0b941978-eec5-468d-8723-8d6373957035","type":"Circle"},{"attributes":{"callback":null,"column_names":["imgs","y","desc","x"],"data":{"desc":["F3Y64770147H3RPA","F3Y64770147H3RPA","F3Y64770147H3RPA","F3Y64770147H3RPA","F3Y64770147H3RPA","F3Y64770147H3RPA","F3Y64770W9BH3RNA","F3Y64770W9BH3RNA","F3Y64770W9BH3RNA","F3Y64831SB3H3RPA","F3Y64831SB3H3RPA","F3Y64831SB3H3RPA","F3Y64831SB3H3RPA","F3Y64831SB3H3RPA","F3Y64930CQ9GY4TA","F3Y64930CQ9GY4TA","F3Y64930CQ9GY4TA","F3Y64930CQ9GY4TA","F3Y64930CQ9GY4TA","F3Y6495012GH3RPA","F3Y6495012GH3RPA","F3Y649702N1H3RNA","F3Y649702N1H3RNA","F3Y649702N1H3RNA","F3Y649702N1H3RNA","F3Y649702N1H3RNA","F3Y64970BCMH3RNA","F3Y64970BCMH3RNA","F3Y64970BCMH3RNA","F3Y64970BCMH3RNA","F3Y64970BCMH3RNA","F3Y650100SYH3RNA","F3Y650100SYH3RNA","F3Y650100SYH3RNA","F3Y650100SYH3RNA","F3Y650100SYH3RNA","F3Y65013L5XGY4TA","F3Y65013L5XGY4TA","F3Y65013L5XGY4TA","F3Y65013L5XGY4TA","F3Y65013L5XGY4TA","F3Y65013L5XGY4TA","F3Y6502018LH3RNA","F3Y6502018LH3RNA","F3Y6502018LH3RNA","F3Y6502018LH3RNA","F3Y6502018LH3RNA","F3Y6502018LH3RNA","F3Y65020LACH3RPA","F3Y65020LACH3RPA","F3Y65020LACH3RPA","F3Y65020LACH3RPA","F3Y65040A8UH3RPA","F3Y65040A8UH3RPA","F3Y65040A8UH3RPA","F3Y65040A8UH3RPA","F3Y65040A8UH3RPA","F3Y65040A8UH3RPA","F3Y65041M9UH3RPA","F3Y65041M9UH3RPA","F3Y65041M9UH3RPA","F3Y65041M9UH3RPA","F3Y65041M9UH3RPA","F3Y65041M9UH3RPA","F3Y65041M9UH3RPA","F3Y650501MXH3RQC","F3Y650501MXH3RQC","F3Y650501MXH3RQC","F3Y650501MXH3RQC","F3Y650501MXH3RQC","F3Y650501MXH3RQC","F3Y650501MYH3RQC","F3Y650501MZH3RQC","F3Y650501MZH3RQC","F3Y650501MZH3RQC","F3Y650501MZH3RQC","F3Y650501MZH3RQC","F3Y650501MZH3RQC","F3Y650501MZH3RQC","F3Y650501MZH3RQC","F3Y65050363H3RQC","F3Y65050363H3RQC","F3Y65050363H3RQC","F3Y65050363H3RQC","F3Y65050363H3RQC","F3Y65050AE0H3RPB","F3Y65050AE3H3RPB","F3Y65050FNYH3RQC","F3Y65050FNYH3RQC","F3Y65050FNYH3RQC","F3Y65050FNYH3RQC","F3Y65050FNYH3RQC","F3Y65050FP0H3RQC","F3Y65050FP0H3RQC","F3Y65050FP0H3RQC","F3Y65050FP0H3RQC","F3Y65050FP0H3RQC","F3Y65050FP0H3RQC","F3Y65050FP0H3RQC","F3Y65050FP1H3RQC","F3Y65050FP1H3RQC","F3Y65050FP1H3RQC","F3Y65050FP1H3RQC" ...

# %%
for label_class in set(labels_all):
    sns_in_label = sns_all[labels_all == label_class]
    print 'the number of class {} is {}'.format(label_class, len(sns_in_label))
    print 'the number of S/Ns: is {}'.format(len(set(sns_in_label)))
    for sn in set(sns_in_label):
        print '\tthe number of S\N {}:{}'.format(sn, len(sns_all[(labels_all == label_class) & (sns_all == sn)]))
# Out:
# the number of class 0 is 64
# the number of S/Ns: is 10
# 	the number of S\N 1:7
# 	the number of S\N 0:8
# 	the number of S\N 3:5
# 	the number of S\N 2:5
# 	the number of S\N 5:7
# 	the number of S\N 4:8
# 	the number of S\N 7:6
# 	the number of S\N 6:7
# 	the number of S\N 9:5
# 	the number of S\N 8:6
# the number of class 3 is 162
# the number of S/Ns: is 31
# 	the number of S\N F3Y649409EAGY4VB:6
# 	the number of S\N F3Y64950W1MGY4RA:6
# 	the number of S\N F3Y65050363H3RQC:6
# 	the number of S\N F3Y65050AE0H3RPB:1
# 	the number of S\N F3Y649512AUGY4TA:1
# 	the number of S\N F3Y65050FNYH3RQC:6
# 	the number of S\N F3Y65060AXEH3RPB:5
# 	the number of S\N F3Y649702N1H3RNA:5
# 	the number of S\N F3Y65040A8UH3RPA:7
# 	the number of S\N F3Y64831SB3H3RPA:6
# 	the number of S\N F3Y64950CK8GY4RA:7
# 	the number of S\N F3Y65041M9UH3RPA:8
# 	the number of S\N F3Y65020LACH3RPA:5
# 	the number of S\N F3Y65050FP1H3RQC:7
# 	the number of S\N F3Y65060AXFH3RPB:6
# 	the number of S\N F3Y65050AE3H3RPB:1
# 	the number of S\N F3Y650100SYH3RNA:6
# 	the number of S\N F3Y64770147H3RPA:7
# 	the number of S\N F3Y64950VRLGY4RA:5
# 	the number of S\N F3Y64950F2QGY4RA:1
# 	the number of S\N F3Y65050FP0H3RQC:8
# 	the number of S\N F3Y6495012GH3RPA:2
# 	the number of S\N F3Y64970BCMH3RNA:6
# 	the number of S\N F3Y650501MYH3RQC:1
# 	the number of S\N F3Y65013L5XGY4TA:7
# 	the number of S\N F3Y650501MXH3RQC:7
# 	the number of S\N F3Y64930CQ9GY4TA:5
# 	the number of S\N F3Y6502018LH3RNA:6
# 	the number of S\N F3Y64770W9BH3RNA:3
# 	the number of S\N F3Y64950FEEGY4RA:7
# 	the number of S\N F3Y650501MZH3RQC:8
