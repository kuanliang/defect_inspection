# %%
from defectlib import load_tensors
from defectlib import load_tensors_all
from defectlib import combine_shuffle_tensors, display_tensor, keras_transform, make_model, train_model
from defectlib import Config, remove_sn, remain_sn
from matplotlib import image
from IPython.display import Image
from tqdm import tqdm, trange
import matplotlib.pyplot as plt
import defectlib
import cv2
import os
import numpy as np
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
defect_dict = load_tensors_all('./defect_tensors_D10/M2800/', width=128)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fbcdccb92334> in <module>()
# ----> 1 defect_dict = load_tensors_all('./defect_tensors_D10/M2800/', width=128)
#
# NameError: name 'load_tensors_all' is not defined

# %%
tensors, labels, sns = combine_shuffle_tensors(defect_dict)
# Out:
# the final tensor should be 307
# number of class 0: 230
# 	number of SN: 15
# number of class 10: 77
# 	number of SN: 6

# %%
display_tensor(tensors, labels, sns)
