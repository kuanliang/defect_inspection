# %%
from defectlib import extract_features_from_defect, train_svm_classifier, plot_tsne
import numpy as np
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
features_all, labels_all, sns_all, images_all = extract_features_from_defect('./ben1214/PMSH/')
# features_test, labels_test, sns_test, images_test = extract_features_from_defect('./defect_tensors_D10', comb=True)

#features_all = np.concatenate((features, features_test))
#labels_all = np.concatenate((labels, labels_test))
#sns_all = np.concatenate((sns, sns_test))
#images_all = np.concatenate((images, images_test))
# Out:
# there are 30 images inside PMSH_7A_c0
# Processing ./ben1214/PMSH/7A/PMSH_7A_c0/F3Y64940NUFH3RPA 7AAAAAA_1.jpg...
# there are 36 images inside PMSH_7A_c8
# Processing ./ben1214/PMSH/7A/PMSH_7A_c8/F3Y64740KMPH3RPA 7AAAAAA_1.jpg...

# %%
plot_tsne(features_all, labels_all, images_all, perplexity=15, interactive=False)

# %%
train_svm_classifier(features_all, labels_all, sns_all, 'model.model', split=True)
# Out:
# train test split == True
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [CV] kernel=linear, C=1 ..............................................
# [CV] ............... kernel=linear, C=1, score=1.000000, total=   0.0s
# [CV] kernel=linear, C=1 ..............................................
# [CV] ............... kernel=linear, C=1, score=1.000000, total=   0.0s
# [CV] kernel=linear, C=1 ..............................................
# [CV] ............... kernel=linear, C=1, score=1.000000, total=   0.0s
# [CV] kernel=linear, C=10 .............................................
# [CV] .............. kernel=linear, C=10, score=1.000000, total=   0.0s
# [CV] kernel=linear, C=10 .............................................
# [CV] .............. kernel=linear, C=10, score=1.000000, total=   0.0s
# [CV] kernel=linear, C=10 .............................................
# [CV] .............. kernel=linear, C=10, score=1.000000, total=   0.0s
# [CV] kernel=linear, C=100 ............................................
# [CV] ............. kernel=linear, C=100, score=1.000000, total=   0.0s
# [CV] kernel=linear, C=100 ............................................
# [CV] ............. kernel=linear, C=100, score=1.000000, total=   0.0s
# [CV] kernel=linear, C=100 ............................................
# [CV] ............. kernel=linear, C=100, score=1.000000, total=   0.0s
# [CV] kernel=linear, C=1000 ...........................................
# [CV] ............ kernel=linear, C=1000, score=1.000000, total=   0.0s
# [CV] kernel=linear, C=1000 ...........................................
# [CV] ............ kernel=linear, C=1000, score=1.000000, total=   0.0s
# [CV] kernel=linear, C=1000 ...........................................
# [CV] ............ kernel=linear, C=1000, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=1, gamma=0.01 .....................................
# [CV] ...... kernel=rbf, C=1, gamma=0.01, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=1, gamma=0.01 .....................................
# [CV] ...... kernel=rbf, C=1, gamma=0.01, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=1, gamma=0.01 .....................................
# [CV] ...... kernel=rbf, C=1, gamma=0.01, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=1, gamma=0.001 ....................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [CV] ..... kernel=rbf, C=1, gamma=0.001, score=0.588235, total=   0.0s
# [CV] kernel=rbf, C=1, gamma=0.001 ....................................
# [CV] ..... kernel=rbf, C=1, gamma=0.001, score=0.562500, total=   0.0s
# [CV] kernel=rbf, C=1, gamma=0.001 ....................................
# [CV] ..... kernel=rbf, C=1, gamma=0.001, score=0.562500, total=   0.0s
# [CV] kernel=rbf, C=1, gamma=0.0001 ...................................
# [CV] .... kernel=rbf, C=1, gamma=0.0001, score=0.588235, total=   0.0s
# [CV] kernel=rbf, C=1, gamma=0.0001 ...................................
# [CV] .... kernel=rbf, C=1, gamma=0.0001, score=0.562500, total=   0.0s
# [CV] kernel=rbf, C=1, gamma=0.0001 ...................................
# [CV] .... kernel=rbf, C=1, gamma=0.0001, score=0.562500, total=   0.0s
# [CV] kernel=rbf, C=1, gamma=1e-05 ....................................
# [CV] ..... kernel=rbf, C=1, gamma=1e-05, score=0.588235, total=   0.0s
# [CV] kernel=rbf, C=1, gamma=1e-05 ....................................
# [CV] ..... kernel=rbf, C=1, gamma=1e-05, score=0.562500, total=   0.0s
# [CV] kernel=rbf, C=1, gamma=1e-05 ....................................
# [CV] ..... kernel=rbf, C=1, gamma=1e-05, score=0.562500, total=   0.0s
# [CV] kernel=rbf, C=10, gamma=0.01 ....................................
# [CV] ..... kernel=rbf, C=10, gamma=0.01, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=10, gamma=0.01 ....................................
# [CV] ..... kernel=rbf, C=10, gamma=0.01, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=10, gamma=0.01 ....................................
# [CV] ..... kernel=rbf, C=10, gamma=0.01, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=10, gamma=0.001 ...................................
# [CV] .... kernel=rbf, C=10, gamma=0.001, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=10, gamma=0.001 ...................................
# [CV] .... kernel=rbf, C=10, gamma=0.001, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=10, gamma=0.001 ...................................
# [CV] .... kernel=rbf, C=10, gamma=0.001, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=10, gamma=0.0001 ..................................
# [CV] ... kernel=rbf, C=10, gamma=0.0001, score=0.588235, total=   0.0s
# [CV] kernel=rbf, C=10, gamma=0.0001 ..................................
# [CV] ... kernel=rbf, C=10, gamma=0.0001, score=0.562500, total=   0.0s
# [CV] kernel=rbf, C=10, gamma=0.0001 ..................................
# [CV] ... kernel=rbf, C=10, gamma=0.0001, score=0.562500, total=   0.0s
# [CV] kernel=rbf, C=10, gamma=1e-05 ...................................
# [CV] .... kernel=rbf, C=10, gamma=1e-05, score=0.588235, total=   0.0s
# [CV] kernel=rbf, C=10, gamma=1e-05 ...................................
# [CV] .... kernel=rbf, C=10, gamma=1e-05, score=0.562500, total=   0.0s
# [CV] kernel=rbf, C=10, gamma=1e-05 ...................................
# [CV] .... kernel=rbf, C=10, gamma=1e-05, score=0.562500, total=   0.0s
# [CV] kernel=rbf, C=100, gamma=0.01 ...................................
# [CV] .... kernel=rbf, C=100, gamma=0.01, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=100, gamma=0.01 ...................................
# [CV] .... kernel=rbf, C=100, gamma=0.01, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=100, gamma=0.01 ...................................
# [CV] .... kernel=rbf, C=100, gamma=0.01, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=100, gamma=0.001 ..................................
# [CV] ... kernel=rbf, C=100, gamma=0.001, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=100, gamma=0.001 ..................................
# [CV] ... kernel=rbf, C=100, gamma=0.001, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=100, gamma=0.001 ..................................
# [CV] ... kernel=rbf, C=100, gamma=0.001, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=100, gamma=0.0001 .................................
# [CV] .. kernel=rbf, C=100, gamma=0.0001, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=100, gamma=0.0001 .................................
# [CV] .. kernel=rbf, C=100, gamma=0.0001, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=100, gamma=0.0001 .................................
# [CV] .. kernel=rbf, C=100, gamma=0.0001, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=100, gamma=1e-05 ..................................
# [CV] ... kernel=rbf, C=100, gamma=1e-05, score=0.588235, total=   0.0s
# [CV] kernel=rbf, C=100, gamma=1e-05 ..................................
# [CV] ... kernel=rbf, C=100, gamma=1e-05, score=0.562500, total=   0.0s
# [CV] kernel=rbf, C=100, gamma=1e-05 ..................................
# [CV] ... kernel=rbf, C=100, gamma=1e-05, score=0.562500, total=   0.0s
# [CV] kernel=rbf, C=1000, gamma=0.01 ..................................
# [CV] ... kernel=rbf, C=1000, gamma=0.01, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=1000, gamma=0.01 ..................................
# [CV] ... kernel=rbf, C=1000, gamma=0.01, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=1000, gamma=0.01 ..................................
# [CV] ... kernel=rbf, C=1000, gamma=0.01, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=1000, gamma=0.001 .................................
# [CV] .. kernel=rbf, C=1000, gamma=0.001, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=1000, gamma=0.001 .................................
# [CV] .. kernel=rbf, C=1000, gamma=0.001, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=1000, gamma=0.001 .................................
# [CV] .. kernel=rbf, C=1000, gamma=0.001, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=1000, gamma=0.0001 ................................
# [CV] . kernel=rbf, C=1000, gamma=0.0001, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=1000, gamma=0.0001 ................................
# [CV] . kernel=rbf, C=1000, gamma=0.0001, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=1000, gamma=0.0001 ................................
# [CV] . kernel=rbf, C=1000, gamma=0.0001, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=1000, gamma=1e-05 .................................
# [CV] .. kernel=rbf, C=1000, gamma=1e-05, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=1000, gamma=1e-05 .................................
# [CV] .. kernel=rbf, C=1000, gamma=1e-05, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=1000, gamma=1e-05 .................................
# [CV] .. kernel=rbf, C=1000, gamma=1e-05, score=1.000000, total=   0.0s
# Cannot save trained svm model to model.model
#
# Best parameters set:
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# Confusion matrix:
# Labels: 0,8
#
# [[9 0]
#  [0 8]]
#
# Classification report:
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00         9
#           8       1.00      1.00      1.00         8
#
# avg / total       1.00      1.00      1.00        17
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed:    0.8s finished
# GridSearchCV(cv=3, error_score='raise',
#        estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False),
#        fit_params={}, iid=True, n_jobs=1,
#        param_grid=[{'kernel': ['linear'], 'C': [1, 10, 100, 1000]}, {'kernel': ['rbf'], 'C': [1, 10, 100, 1000], 'gamma': [0.01, 0.001, 0.0001, 1e-05]}],
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=3)

# %%
from bokeh.plotting import figure, output_notebook
output_notebook()
from bokeh.plotting import figure, show
from tsne import bh_sne
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e0e3312e-5c93-473e-8d4c-dda6c1388722">Loading BokehJS ...</span>
#     </div>

# %%
vis_data = bh_sne(features_all, perplexity=15)
vis_x = vis_data[:,0]
vis_y = vis_data[:,1]

vis_data_0 = vis_data[labels_all=='0']
vis_data_8 = vis_data[labels_all=='8']

vis_data_0_x = vis_data_0[:,0]
vis_data_0_y = vis_data_0[:,1]
vis_data_8_x = vis_data_8[:,0]
vis_data_8_y = vis_data_8[:,1]

# %%
from bokeh.plotting import figure, output_file, show, ColumnDataSource
from bokeh.models import HoverTool


source1 = ColumnDataSource(
        data=dict(
            x=vis_data_0_x,
            y=vis_data_0_y,
            desc=sns_all[labels_all=='0'],
            imgs = images_all[labels_all=='0']

        )
    )


source2 = ColumnDataSource(
        data=dict(
            x=vis_data_8_x,
            y=vis_data_8_y,
            desc=sns_all[labels_all=='8'],
            imgs=images_all[labels_all=='8']
        )
    )



hover = HoverTool(
        tooltips="""
        <div>
            <div>
                <img
                    src="@imgs" height="160" alt="@imgs" width="160"
                    style="float: left; margin: 0px 15px 15px 0px;"
                    border="2"
                ></img>
            </div>
            <div>
                <span style="font-size: 17px; font-weight: bold;">@desc</span>
            </div>
        </div>
        """
    )

p = figure(plot_width=400, plot_height=400, tools=[hover],
           title="Mouse over the dots")

p.circle('x', 'y', size=20, alpha=0.5, color='green', source=source1)
p.circle('x', 'y', size=20, alpha=0.5, color='red', source=source2)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="08cc3284-1aac-45ac-8f76-9f46faacf5c8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#08cc3284-1aac-45ac-8f76-9f46faacf5c8").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("08cc3284-1aac-45ac-8f76-9f46faacf5c8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '08cc3284-1aac-45ac-8f76-9f46faacf5c8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"5408de30-02af-49bf-8d78-ef3f2a95a1aa":{"roots":{"references":[{"attributes":{"callback":null},"id":"20010418-64e3-4d84-a14a-4ef12f949fd9","type":"DataRange1d"},{"attributes":{"formatter":{"id":"de5ed3c4-ad0a-4cf4-ab0d-73e26519e710","type":"BasicTickFormatter"},"plot":{"id":"4dff13c0-bb48-4827-93fa-5f96f230cdee","subtype":"Figure","type":"Plot"},"ticker":{"id":"ea1a7abd-1a86-49c2-abb3-5424f330b79c","type":"BasicTicker"}},"id":"8b35d591-24bd-4bd7-8ecd-78bb9276cbba","type":"LinearAxis"},{"attributes":{"data_source":{"id":"41078140-7cbe-4e7d-9449-a99573f63a45","type":"ColumnDataSource"},"glyph":{"id":"6139aa4a-c5f5-46e8-8977-60cde53a14d3","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"37120eb6-3f08-416e-ba44-246ca7e1e1bd","type":"Circle"},"selection_glyph":null},"id":"d3aee269-3124-4329-8638-571e91cb5439","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":20},"x":{"field":"x"},"y":{"field":"y"}},"id":"37120eb6-3f08-416e-ba44-246ca7e1e1bd","type":"Circle"},{"attributes":{},"id":"19ba396f-62ba-4d3c-a4b8-5677db342699","type":"BasicTickFormatter"},{"attributes":{},"id":"82c8940b-d134-4009-bc23-a55077d5a0b8","type":"BasicTicker"},{"attributes":{"below":[{"id":"0f63fb54-ae77-4103-98bd-08e427a6bd0e","type":"LinearAxis"}],"left":[{"id":"8b35d591-24bd-4bd7-8ecd-78bb9276cbba","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"0f63fb54-ae77-4103-98bd-08e427a6bd0e","type":"LinearAxis"},{"id":"e9687647-b4b8-43b7-8367-1101aed5e19a","type":"Grid"},{"id":"8b35d591-24bd-4bd7-8ecd-78bb9276cbba","type":"LinearAxis"},{"id":"0dab4825-49d4-47a0-81cb-bc451aec9384","type":"Grid"},{"id":"d3aee269-3124-4329-8638-571e91cb5439","type":"GlyphRenderer"},{"id":"ac4973b1-99b4-49ce-992e-0a6c83d6a1ee","type":"GlyphRenderer"}],"title":{"id":"205a66c7-3d05-45f8-af11-9b644906d703","type":"Title"},"tool_events":{"id":"62daf62f-13c0-40f3-b531-81eaf7ea08e7","type":"ToolEvents"},"toolbar":{"id":"edd2397e-8321-46c7-97fd-583e00a842a6","type":"Toolbar"},"x_range":{"id":"20010418-64e3-4d84-a14a-4ef12f949fd9","type":"DataRange1d"},"y_range":{"id":"e4d5be25-49ac-4034-a3d5-67ab7bd9bf86","type":"DataRange1d"}},"id":"4dff13c0-bb48-4827-93fa-5f96f230cdee","subtype":"Figure","type":"Plot"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"7274dc76-bece-4573-92df-3e08d8976b9e","type":"HoverTool"}]},"id":"edd2397e-8321-46c7-97fd-583e00a842a6","type":"Toolbar"},{"attributes":{"plot":{"id":"4dff13c0-bb48-4827-93fa-5f96f230cdee","subtype":"Figure","type":"Plot"},"ticker":{"id":"82c8940b-d134-4009-bc23-a55077d5a0b8","type":"BasicTicker"}},"id":"e9687647-b4b8-43b7-8367-1101aed5e19a","type":"Grid"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":20},"x":{"field":"x"},"y":{"field":"y"}},"id":"ab9beff1-b3df-47c7-85af-f19f99a6d89a","type":"Circle"},{"attributes":{"callback":null,"plot":{"id":"4dff13c0-bb48-4827-93fa-5f96f230cdee","subtype":"Figure","type":"Plot"},"tooltips":"\n        <div>\n            <div>\n                <img\n                    src=\"@imgs\" height=\"160\" alt=\"@imgs\" width=\"160\"\n                    style=\"float: left; margin: 0px 15px 15px 0px;\"\n                    border=\"2\"\n                ></img>\n            </div>\n            <div>\n                <span style=\"font-size: 17px; font-weight: bold;\">@desc</span>\n            </div>\n        </div>\n        "},"id":"7274dc76-bece-4573-92df-3e08d8976b9e","type":"HoverTool"},{"attributes":{"dimension":1,"plot":{"id":"4dff13c0-bb48-4827-93fa-5f96f230cdee","subtype":"Figure","type":"Plot"},"ticker":{"id":"ea1a7abd-1a86-49c2-abb3-5424f330b79c","type":"BasicTicker"}},"id":"0dab4825-49d4-47a0-81cb-bc451aec9384","type":"Grid"},{"attribute ...

# %%
for label_class in set(labels_all):
    sns_in_label = sns_all[labels_all == label_class]
    print 'the number of class {} is {}'.format(label_class, len(sns_in_label))
    print 'the number of S/Ns: is {}'.format(len(set(sns_in_label)))
    for sn in set(sns_in_label):
        print '\tthe number of S\N {}:{}'.format(sn, len(sns_all[(labels_all == label_class) & (sns_all == sn)]))
# Out:
# the number of class 0 is 30
# the number of S/Ns: is 15
# 	the number of S\N F3Y64940NUFH3RPA:2
# 	the number of S\N F3Y649500C1H3RPA:2
# 	the number of S\N F3Y649501XRH3RPA:2
# 	the number of S\N F3Y649501JVH3RPA:2
# 	the number of S\N F3Y649505FSH3RPA:2
# 	the number of S\N F3Y649501FKH3RPA:2
# 	the number of S\N F3Y64950033H3RPA:2
# 	the number of S\N F3Y6495015AH3RPA:2
# 	the number of S\N F3Y64950037H3RPA:2
# 	the number of S\N F3Y649501QGH3RPA:2
# 	the number of S\N F3Y649500P8H3RPA:2
# 	the number of S\N F3Y649503XLH3RPA:2
# 	the number of S\N F3Y649501JYH3RPA:2
# 	the number of S\N F3Y6495014NH3RPA:2
# 	the number of S\N F3Y649500SHH3RPA:2
# the number of class 8 is 36
# the number of S/Ns: is 18
# 	the number of S\N F3Y65030ETLGY4TA:2
# 	the number of S\N F3Y650507GGGY4VC:2
# 	the number of S\N F3Y64910D43H3RPA:2
# 	the number of S\N F3Y65013C0BGY4TA:2
# 	the number of S\N F3Y650121PEGY4TA:2
# 	the number of S\N F3Y65030S83GY4RA:2
# 	the number of S\N F3Y649615TQGY4TA:2
# 	the number of S\N F3Y64831GC1H3RPA:2
# 	the number of S\N F3Y64740KMPH3RPA:2
# 	the number of S\N F3Y649409P4GY4TA:2
# 	the number of S\N F3Y64841XPMH3RPA:2
# 	the number of S\N F3Y64760V4JH3RNA:2
# 	the number of S\N F3Y650137RMGY4TA:2
# 	the number of S\N F3Y65030ETKGY4TA:2
# 	the number of S\N F3Y64950W29GY4RA:2
# 	the number of S\N F3Y650508URGY4VC:2
# 	the number of S\N F3Y65030G7BGY4TA:2
# 	the number of S\N F3Y65030E7KGY4TA:2
