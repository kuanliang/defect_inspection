# %%
from defectlib import extract_features_from_defect, train_svm_classifier, plot_tsne
import numpy as np
# %matplotlib inline

# %%
features_all, labels_all, sns_all, images_all = extract_features_from_defect('./ben1214/U2402/')
# features_test, labels_test, sns_test, images_test = extract_features_from_defect('./defect_tensors_D10', comb=True)

#features_all = np.concatenate((features, features_test))
#labels_all = np.concatenate((labels, labels_test))
#sns_all = np.concatenate((sns, sns_test))
#images_all = np.concatenate((images, images_test))
# Out:
# there are 30 images inside U2402_7A_c0
# Processing ./ben1214/U2402/7A/U2402_7A_c0/F3Y64940NUFH3RPA 7AAAAAA_1.jpg...
# there are 60 images inside U2402_7A_c10
# Processing ./ben1214/U2402/7A/U2402_7A_c10/F3Y65010KQFGY4TA 7AAAAAA_1.jpg...

# %%
plot_tsne(features_all, +labels_all, images_all, perplexity=15, interactive=False)

# %%
train_svm_classifier(features_all, labels_all, sns_all, 'model.model', split=True)
# Out:
# train test split == True
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [CV] kernel=linear, C=1 ..............................................
# [CV] ............... kernel=linear, C=1, score=0.956522, total=   0.0s
# [CV] kernel=linear, C=1 ..............................................
# [CV] ............... kernel=linear, C=1, score=1.000000, total=   0.0s
# [CV] kernel=linear, C=1 ..............................................
# [CV] ............... kernel=linear, C=1, score=1.000000, total=   0.0s
# [CV] kernel=linear, C=10 .............................................
# [CV] .............. kernel=linear, C=10, score=0.956522, total=   0.0s
# [CV] kernel=linear, C=10 .............................................
# [CV] .............. kernel=linear, C=10, score=1.000000, total=   0.0s
# [CV] kernel=linear, C=10 .............................................
# [CV] .............. kernel=linear, C=10, score=1.000000, total=   0.0s
# [CV] kernel=linear, C=100 ............................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [CV] ............. kernel=linear, C=100, score=0.956522, total=   0.0s
# [CV] kernel=linear, C=100 ............................................
# [CV] ............. kernel=linear, C=100, score=1.000000, total=   0.0s
# [CV] kernel=linear, C=100 ............................................
# [CV] ............. kernel=linear, C=100, score=1.000000, total=   0.0s
# [CV] kernel=linear, C=1000 ...........................................
# [CV] ............ kernel=linear, C=1000, score=0.956522, total=   0.0s
# [CV] kernel=linear, C=1000 ...........................................
# [CV] ............ kernel=linear, C=1000, score=1.000000, total=   0.0s
# [CV] kernel=linear, C=1000 ...........................................
# [CV] ............ kernel=linear, C=1000, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=1, gamma=0.01 .....................................
# [CV] ...... kernel=rbf, C=1, gamma=0.01, score=0.826087, total=   0.0s
# [CV] kernel=rbf, C=1, gamma=0.01 .....................................
# [CV] ...... kernel=rbf, C=1, gamma=0.01, score=0.863636, total=   0.0s
# [CV] kernel=rbf, C=1, gamma=0.01 .....................................
# [CV] ...... kernel=rbf, C=1, gamma=0.01, score=0.909091, total=   0.0s
# [CV] kernel=rbf, C=1, gamma=0.001 ....................................
# [CV] ..... kernel=rbf, C=1, gamma=0.001, score=0.652174, total=   0.0s
# [CV] kernel=rbf, C=1, gamma=0.001 ....................................
# [CV] ..... kernel=rbf, C=1, gamma=0.001, score=0.636364, total=   0.0s
# [CV] kernel=rbf, C=1, gamma=0.001 ....................................
# [CV] ..... kernel=rbf, C=1, gamma=0.001, score=0.636364, total=   0.0s
# [CV] kernel=rbf, C=1, gamma=0.0001 ...................................
# [CV] .... kernel=rbf, C=1, gamma=0.0001, score=0.652174, total=   0.0s
# [CV] kernel=rbf, C=1, gamma=0.0001 ...................................
# [CV] .... kernel=rbf, C=1, gamma=0.0001, score=0.636364, total=   0.0s
# [CV] kernel=rbf, C=1, gamma=0.0001 ...................................
# [CV] .... kernel=rbf, C=1, gamma=0.0001, score=0.636364, total=   0.0s
# [CV] kernel=rbf, C=1, gamma=1e-05 ....................................
# [CV] ..... kernel=rbf, C=1, gamma=1e-05, score=0.652174, total=   0.0s
# [CV] kernel=rbf, C=1, gamma=1e-05 ....................................
# [CV] ..... kernel=rbf, C=1, gamma=1e-05, score=0.636364, total=   0.0s
# [CV] kernel=rbf, C=1, gamma=1e-05 ....................................
# [CV] ..... kernel=rbf, C=1, gamma=1e-05, score=0.636364, total=   0.0s
# [CV] kernel=rbf, C=10, gamma=0.01 ....................................
# [CV] ..... kernel=rbf, C=10, gamma=0.01, score=0.956522, total=   0.0s
# [CV] kernel=rbf, C=10, gamma=0.01 ....................................
# [CV] ..... kernel=rbf, C=10, gamma=0.01, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=10, gamma=0.01 ....................................
# [CV] ..... kernel=rbf, C=10, gamma=0.01, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=10, gamma=0.001 ...................................
# [CV] .... kernel=rbf, C=10, gamma=0.001, score=0.913043, total=   0.0s
# [CV] kernel=rbf, C=10, gamma=0.001 ...................................
# [CV] .... kernel=rbf, C=10, gamma=0.001, score=0.954545, total=   0.0s
# [CV] kernel=rbf, C=10, gamma=0.001 ...................................
# [CV] .... kernel=rbf, C=10, gamma=0.001, score=0.954545, total=   0.0s
# [CV] kernel=rbf, C=10, gamma=0.0001 ..................................
# [CV] ... kernel=rbf, C=10, gamma=0.0001, score=0.652174, total=   0.0s
# [CV] kernel=rbf, C=10, gamma=0.0001 ..................................
# [CV] ... kernel=rbf, C=10, gamma=0.0001, score=0.636364, total=   0.0s
# [CV] kernel=rbf, C=10, gamma=0.0001 ..................................
# [CV] ... kernel=rbf, C=10, gamma=0.0001, score=0.636364, total=   0.0s
# [CV] kernel=rbf, C=10, gamma=1e-05 ...................................
# [CV] .... kernel=rbf, C=10, gamma=1e-05, score=0.652174, total=   0.0s
# [CV] kernel=rbf, C=10, gamma=1e-05 ...................................
# [CV] .... kernel=rbf, C=10, gamma=1e-05, score=0.636364, total=   0.0s
# [CV] kernel=rbf, C=10, gamma=1e-05 ...................................
# [CV] .... kernel=rbf, C=10, gamma=1e-05, score=0.636364, total=   0.0s
# [CV] kernel=rbf, C=100, gamma=0.01 ...................................
# [CV] .... kernel=rbf, C=100, gamma=0.01, score=0.956522, total=   0.0s
# [CV] kernel=rbf, C=100, gamma=0.01 ...................................
# [CV] .... kernel=rbf, C=100, gamma=0.01, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=100, gamma=0.01 ...................................
# [CV] .... kernel=rbf, C=100, gamma=0.01, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=100, gamma=0.001 ..................................
# [CV] ... kernel=rbf, C=100, gamma=0.001, score=0.956522, total=   0.0s
# [CV] kernel=rbf, C=100, gamma=0.001 ..................................
# [CV] ... kernel=rbf, C=100, gamma=0.001, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=100, gamma=0.001 ..................................
# [CV] ... kernel=rbf, C=100, gamma=0.001, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=100, gamma=0.0001 .................................
# [CV] .. kernel=rbf, C=100, gamma=0.0001, score=0.913043, total=   0.0s
# [CV] kernel=rbf, C=100, gamma=0.0001 .................................
# [CV] .. kernel=rbf, C=100, gamma=0.0001, score=0.954545, total=   0.0s
# [CV] kernel=rbf, C=100, gamma=0.0001 .................................
# [CV] .. kernel=rbf, C=100, gamma=0.0001, score=0.954545, total=   0.0s
# [CV] kernel=rbf, C=100, gamma=1e-05 ..................................
# [CV] ... kernel=rbf, C=100, gamma=1e-05, score=0.652174, total=   0.0s
# [CV] kernel=rbf, C=100, gamma=1e-05 ..................................
# [CV] ... kernel=rbf, C=100, gamma=1e-05, score=0.636364, total=   0.0s
# [CV] kernel=rbf, C=100, gamma=1e-05 ..................................
# [CV] ... kernel=rbf, C=100, gamma=1e-05, score=0.636364, total=   0.0s
# [CV] kernel=rbf, C=1000, gamma=0.01 ..................................
# [CV] ... kernel=rbf, C=1000, gamma=0.01, score=0.956522, total=   0.0s
# [CV] kernel=rbf, C=1000, gamma=0.01 ..................................
# [CV] ... kernel=rbf, C=1000, gamma=0.01, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=1000, gamma=0.01 ..................................
# [CV] ... kernel=rbf, C=1000, gamma=0.01, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=1000, gamma=0.001 .................................
# [CV] .. kernel=rbf, C=1000, gamma=0.001, score=0.956522, total=   0.0s
# [CV] kernel=rbf, C=1000, gamma=0.001 .................................
# [CV] .. kernel=rbf, C=1000, gamma=0.001, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=1000, gamma=0.001 .................................
# [CV] .. kernel=rbf, C=1000, gamma=0.001, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=1000, gamma=0.0001 ................................
# [CV] . kernel=rbf, C=1000, gamma=0.0001, score=0.956522, total=   0.0s
# [CV] kernel=rbf, C=1000, gamma=0.0001 ................................
# [CV] . kernel=rbf, C=1000, gamma=0.0001, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=1000, gamma=0.0001 ................................
# [CV] . kernel=rbf, C=1000, gamma=0.0001, score=1.000000, total=   0.0s
# [CV] kernel=rbf, C=1000, gamma=1e-05 .................................
# [CV] .. kernel=rbf, C=1000, gamma=1e-05, score=0.913043, total=   0.0s
# [CV] kernel=rbf, C=1000, gamma=1e-05 .................................
# [CV] .. kernel=rbf, C=1000, gamma=1e-05, score=0.954545, total=   0.0s
# [CV] kernel=rbf, C=1000, gamma=1e-05 .................................
# [CV] .. kernel=rbf, C=1000, gamma=1e-05, score=0.954545, total=   0.0s
# Cannot save trained svm model to model.model
#
# Best parameters set:
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# Confusion matrix:
# Labels: 0,10
#
# [[ 6  0]
#  [ 2 15]]
#
# Classification report:
#              precision    recall  f1-score   support
#
#           0       0.75      1.00      0.86         6
#          10       1.00      0.88      0.94        17
#
# avg / total       0.93      0.91      0.92        23
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed:    2.1s finished
# GridSearchCV(cv=3, error_score='raise',
#        estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False),
#        fit_params={}, iid=True, n_jobs=1,
#        param_grid=[{'kernel': ['linear'], 'C': [1, 10, 100, 1000]}, {'kernel': ['rbf'], 'C': [1, 10, 100, 1000], 'gamma': [0.01, 0.001, 0.0001, 1e-05]}],
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=3)

# %%
from bokeh.plotting import figure, output_notebook
output_notebook()
from bokeh.plotting import figure, show
from tsne import bh_sne
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3a81b99b-dbda-4cd6-9dd8-daec58a57afd">Loading BokehJS ...</span>
#     </div>

# %%
vis_data = bh_sne(features_all, perplexity=10)
vis_x = vis_data[:,0]
vis_y = vis_data[:,1]

vis_data_0 = vis_data[labels_all=='0']
vis_data_10 = vis_data[labels_all=='10']

vis_data_0_x = vis_data_0[:,0]
vis_data_0_y = vis_data_0[:,1]
vis_data_10_x = vis_data_10[:,0]
vis_data_10_y = vis_data_10[:,1]

# %%
# %matplotlib inline

# %%
from bokeh.plotting import figure, output_file, show, ColumnDataSource
from bokeh.models import HoverTool


source1 = ColumnDataSource(
        data=dict(
            x=vis_data_0_x,
            y=vis_data_0_y,
            desc=sns_all[labels_all=='0'],
            imgs = images_all[labels_all=='0']

        )
    )

source2 = ColumnDataSource(
        data=dict(
            x=vis_data_10_x,
            y=vis_data_10_y,
            desc=sns_all[labels_all=='10'],
            imgs=images_all[labels_all=='10']
        )
    )





hover = HoverTool(
        tooltips="""
        <div>
            <div>
                <img
                    src="@imgs" height="80" alt="@imgs" width="80"
                    style="float: left; margin: 0px 15px 15px 0px;"
                    border="2"
                ></img>
            </div>
            <div>
                <span style="font-size: 17px; font-weight: bold;">@desc</span>
            </div>
        </div>
        """
    )

p = figure(plot_width=800, plot_height=800, tools=[hover],
           title="Mouse over the dots")

p.circle('x', 'y', size=20, alpha=0.5, color='green', source=source1)
p.circle('x', 'y', size=20, alpha=0.5, color='red', source=source2)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="16ee0191-9ff4-412d-9cdc-d3346debfa12"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#16ee0191-9ff4-412d-9cdc-d3346debfa12").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("16ee0191-9ff4-412d-9cdc-d3346debfa12");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '16ee0191-9ff4-412d-9cdc-d3346debfa12' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"e2380dba-6402-4dff-bbf9-3346373b61ad":{"roots":{"references":[{"attributes":{"plot":null,"text":"Mouse over the dots"},"id":"135842af-a1be-48f0-ace6-0b3207c0c37c","type":"Title"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":20},"x":{"field":"x"},"y":{"field":"y"}},"id":"0660e9e4-0239-43b5-871e-7874b51cf7d3","type":"Circle"},{"attributes":{},"id":"d12e5298-d422-40d1-9a6c-95683055b986","type":"BasicTicker"},{"attributes":{"formatter":{"id":"be234bc4-d0a9-4092-8202-949fd3a640ab","type":"BasicTickFormatter"},"plot":{"id":"38c2efc1-02c2-4dd2-be44-6adf4e264980","subtype":"Figure","type":"Plot"},"ticker":{"id":"cc21d361-0292-4db1-951c-8ab65f73dab2","type":"BasicTicker"}},"id":"ca3d28fc-9b74-40ed-aa46-2bca0e66dcba","type":"LinearAxis"},{"attributes":{},"id":"a5d45ef6-9219-4657-b5a9-1da6b69f8701","type":"ToolEvents"},{"attributes":{"callback":null,"plot":{"id":"38c2efc1-02c2-4dd2-be44-6adf4e264980","subtype":"Figure","type":"Plot"},"tooltips":"\n        <div>\n            <div>\n                <img\n                    src=\"@imgs\" height=\"80\" alt=\"@imgs\" width=\"80\"\n                    style=\"float: left; margin: 0px 15px 15px 0px;\"\n                    border=\"2\"\n                ></img>\n            </div>\n            <div>\n                <span style=\"font-size: 17px; font-weight: bold;\">@desc</span>\n            </div>\n        </div>\n        "},"id":"4501679a-1fea-44b6-9166-85c0eb3de666","type":"HoverTool"},{"attributes":{"below":[{"id":"ca3d28fc-9b74-40ed-aa46-2bca0e66dcba","type":"LinearAxis"}],"left":[{"id":"773e2226-c3ce-473f-b972-ca6c5da75ede","type":"LinearAxis"}],"plot_height":800,"plot_width":800,"renderers":[{"id":"ca3d28fc-9b74-40ed-aa46-2bca0e66dcba","type":"LinearAxis"},{"id":"0556abab-bd6b-4c0e-80bd-0863ac0169a9","type":"Grid"},{"id":"773e2226-c3ce-473f-b972-ca6c5da75ede","type":"LinearAxis"},{"id":"d0fda464-14c7-410d-b4c6-94c82920fad5","type":"Grid"},{"id":"acd278de-909e-40c1-84f3-eb4d4841cad3","type":"GlyphRenderer"},{"id":"3496b3c4-dc20-4004-bbc2-c883042d7f41","type":"GlyphRenderer"}],"title":{"id":"135842af-a1be-48f0-ace6-0b3207c0c37c","type":"Title"},"tool_events":{"id":"a5d45ef6-9219-4657-b5a9-1da6b69f8701","type":"ToolEvents"},"toolbar":{"id":"7ec4f639-a3fd-4b89-903a-dc89ad91fe1e","type":"Toolbar"},"x_range":{"id":"957e9d2c-00b4-4214-af1a-9dfa849a58ad","type":"DataRange1d"},"y_range":{"id":"024fb7dc-d7a4-4073-b48d-b90893881d70","type":"DataRange1d"}},"id":"38c2efc1-02c2-4dd2-be44-6adf4e264980","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"be234bc4-d0a9-4092-8202-949fd3a640ab","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"75abecd4-bb74-4227-bdbb-c08a45cb0bd9","type":"ColumnDataSource"},"glyph":{"id":"b56474af-ce2c-40b2-8030-a6232daa480e","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"49b2ca68-246b-402f-8066-2bf3083d6158","type":"Circle"},"selection_glyph":null},"id":"acd278de-909e-40c1-84f3-eb4d4841cad3","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"957e9d2c-00b4-4214-af1a-9dfa849a58ad","type":"DataRange1d"},{"attributes":{"plot":{"id":"38c2efc1-02c2-4dd2-be44-6adf4e264980","subtype":"Figure","type":"Plot"},"ticker":{"id":"cc21d361-0292-4db1-951c-8ab65f73dab2","type":"BasicTicker"}},"id":"0556abab-bd6b-4c0e-80bd-0863ac0169a9","type":"Grid"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":20},"x":{"field":"x"},"y":{"field":"y"}},"id":"49b2ca68-246b-402f-8066-2bf3083d6158","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"red"},"line_alpha":{"value":0.5},"line_color":{"value":"red"},"size":{"units":"screen","value":20},"x":{"field":"x"},"y":{"field":"y"}},"id":"e638bc01-c2dc-4af9-80f5-629489ae156e","type":"Circle"},{"attributes":{"call ...

# %%
for label_class in set(labels_all):
    sns_in_label = sns_all[labels_all == label_class]
    print 'the number of class {} is {}'.format(label_class, len(sns_in_label))
    print 'the number of S/Ns: is {}'.format(len(set(sns_in_label)))
    for sn in set(sns_in_label):
        print '\tthe number of S\N {}:{}'.format(sn, len(sns_all[(labels_all == label_class) & (sns_all == sn)]))
# Out:
# the number of class 0 is 30
# the number of S/Ns: is 15
# 	the number of S\N F3Y64940NUFH3RPA:2
# 	the number of S\N F3Y649500C1H3RPA:2
# 	the number of S\N F3Y649501XRH3RPA:2
# 	the number of S\N F3Y649501JVH3RPA:2
# 	the number of S\N F3Y649505FSH3RPA:2
# 	the number of S\N F3Y649501FKH3RPA:2
# 	the number of S\N F3Y64950033H3RPA:2
# 	the number of S\N F3Y6495015AH3RPA:2
# 	the number of S\N F3Y64950037H3RPA:2
# 	the number of S\N F3Y649501QGH3RPA:2
# 	the number of S\N F3Y649500P8H3RPA:2
# 	the number of S\N F3Y649503XLH3RPA:2
# 	the number of S\N F3Y649501JYH3RPA:2
# 	the number of S\N F3Y6495014NH3RPA:2
# 	the number of S\N F3Y649500SHH3RPA:2
# the number of class 10 is 60
# the number of S/Ns: is 30
# 	the number of S\N F3Y65040RK6GY4TA:2
# 	the number of S\N F3Y65060BT2GY4TB:2
# 	the number of S\N F3Y65050KQUGY4TB:2
# 	the number of S\N F3Y650501BGGY4TB:2
# 	the number of S\N F3Y6503050JGY4RA:2
# 	the number of S\N F3Y650500UXGY4RB:2
# 	the number of S\N F3Y65030EFJGY4RA:2
# 	the number of S\N F3Y65060CE5GY4TB:2
# 	the number of S\N F3Y65050MDEGY4TB:2
# 	the number of S\N F3Y650502ZCGY4TB:2
# 	the number of S\N F3Y6505057QGY4RB:2
# 	the number of S\N F3Y650500FXGY4TB:2
# 	the number of S\N F3Y650502E0GY4TB:2
# 	the number of S\N F3Y650504QJGY4RB:2
# 	the number of S\N F3Y65020LVXGY4RA:2
# 	the number of S\N F3Y65060F75GY4TB:2
# 	the number of S\N F3Y65012WSYGY4TA:2
# 	the number of S\N F3Y650502E2GY4TB:2
# 	the number of S\N F3Y65060FGCGY4TB:2
# 	the number of S\N F3Y650303PNGY4RA:2
# 	the number of S\N F3Y650501CDGY4TB:2
# 	the number of S\N F3Y650500S3GY4TB:2
# 	the number of S\N F3Y65010KQFGY4TA:2
# 	the number of S\N F3Y650305HEGY4RA:2
# 	the number of S\N F3Y65031RZLGY4TA:2
# 	the number of S\N F3Y65020G4HGY4RA:2
# 	the number of S\N F3Y65060G8BGY4TB:2
# 	the number of S\N F3Y650500S2GY4TB:2
# 	the number of S\N F3Y65040TBQGY4TA:2
# 	the number of S\N F3Y65050JVVGY4RB:2

# %%
print 'test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f3e50bd42a45> in <module>()
# ----> 1 print test
#
# NameError: name 'test' is not defined
